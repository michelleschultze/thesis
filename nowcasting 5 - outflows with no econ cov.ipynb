# %% [markdown]
# # Thesis: Nowcasting for Migrant Flows and Stocks Using Scikit-Learn Pipeline
#
# -   Name: Michelle Schultze
# -   Date: 24 March 2025
#
# This file's purpose is to extend the 2021-23 flow and 2010-16 stock variables to span 2018-24 (yearly) and 2010-24 (monthly), respectively. To do so, we will leverage scikit-learn to streamline the process of tuning, evaluating, selecting, and predicting with various machine learning models.

# %% [markdown]
# ## __Part 1:__ Extending the 2021-23 annual flows dataset

# %% [markdown]
# ### Preprocessing the data

# %%
# Load in the full dataset with the full range of 2018-2024 data. 

import pandas as pd

# Load the data
file_path = "/Users/michelle/Documents/thesis/region-year-data.csv"
df = pd.read_csv(file_path)

# Extract columns containing "flow" as y_{name}
y = df.filter(like="flow").add_prefix("y_")

# Split y into separate variables based on column names
for column in y.columns:
    globals()[column] = y[column]

# Extract X (all other columns that are NOT in y)
X = df.drop(columns=df.filter(like="flow").columns)

# Display summary
print("Y shape:", y.shape)
print("X shape:", X.shape)

#print(y_Inflow.head())
# Out:
# Y shape: (567, 3)
# X shape: (567, 196)

# %%
column_names = X.columns.tolist()
#print(column_names)
X = X.loc[:, : "count_zolotaya_korona_average_log_lag"]
column_names = X.columns.tolist()
print(column_names)
# Out:
# ['Region', 'Year', 'count_ailyk_sum', 'count_ailyk_average', 'count_aviabilet_bishkek_sum', 'count_aviabilet_bishkek_average', 'count_bilet_bishkek_sum', 'count_bilet_bishkek_average', 'count_jumush_izdeim_sum', 'count_jumush_izdeim_average', 'count_jumush_sum', 'count_jumush_average', 'count_perevod_deneg_v_kyrgyzstan_sum', 'count_perevod_deneg_v_kyrgyzstan_average', 'count_perevod_deneg_sum', 'count_perevod_deneg_average', 'count_poisk_raboty_sum', 'count_poisk_raboty_average', 'count_rabota_sum', 'count_rabota_average', 'count_unistream_kyrgyzstan_sum', 'count_unistream_kyrgyzstan_average', 'count_unistream_sum', 'count_unistream_average', 'count_vakancii_sum', 'count_vakancii_average', 'count_zarplata_sum', 'count_zarplata_average', 'count_zolotaya_korona_kyrgyzstan_sum', 'count_zolotaya_korona_kyrgyzstan_average', 'count_zolotaya_korona_sum', 'count_zolotaya_korona_average', 'pct_ailyk_average', 'pct_aviabilet_bishkek_average', 'pct_bilet_bishkek_average', 'pct_jumush_izdeim_average', 'pct_jumush_average', 'pct_perevod_deneg_v_kyrgyzstan_average', 'pct_perevod_deneg_average', 'pct_poisk_raboty_average', 'pct_rabota_average', 'pct_unistream_kyrgyzstan_average', 'pct_unistream_average', 'pct_vakancii_average', 'pct_zarplata_average', 'pct_zolotaya_korona_kyrgyzstan_average', 'pct_zolotaya_korona_average', 'ratio_work', 'ratio_job_search', 'ratio_money_transfer', 'ratio_unistream', 'ratio_zolotaya_korona', 'count_ailyk_sum_log', 'count_ailyk_average_log', 'count_aviabilet_bishkek_sum_log', 'count_aviabilet_bishkek_average_log', 'count_bilet_bishkek_sum_log', 'count_bilet_bishkek_average_log', 'count_jumush_izdeim_sum_log', 'count_jumush_izdeim_average_log', 'count_jumush_sum_log', 'count_jumush_average_log', 'count_perevod_deneg_v_kyrgyzstan_sum_log', 'count_perevod_deneg_v_kyrgyzstan_average_log', 'count_perevod_deneg_sum_log', 'count_perevod_deneg_average_log', 'count_poisk_raboty_sum_log', 'count_poisk_raboty_average_log', 'count_rabota_sum_log', 'count_rabota_average_log', 'count_unistream_kyrgyzstan_sum_log', 'count_unistream_kyrgyzstan_average_log', 'count_unistream_sum_log', 'count_unistream_average_log', 'count_vakancii_sum_log', 'count_vakancii_average_log', 'count_zarplata_sum_log', 'count_zarplata_average_log', 'count_zolotaya_korona_kyrgyzstan_sum_log', 'count_zolotaya_korona_kyrgyzstan_average_log', 'count_zolotaya_korona_sum_log', 'count_zolotaya_korona_average_log', 'count_ailyk_sum_lag', 'count_ailyk_average_lag', 'count_aviabilet_bishkek_sum_lag', 'count_aviabilet_bishkek_average_lag', 'count_bilet_bishkek_sum_lag', 'count_bilet_bishkek_average_lag', 'count_jumush_izdeim_sum_lag', 'count_jumush_izdeim_average_lag', 'count_jumush_sum_lag', 'count_jumush_average_lag', 'count_perevod_deneg_v_kyrgyzstan_sum_lag', 'count_perevod_deneg_v_kyrgyzstan_average_lag', 'count_perevod_deneg_sum_lag', 'count_perevod_deneg_average_lag', 'count_poisk_raboty_sum_lag', 'count_poisk_raboty_average_lag', 'count_rabota_sum_lag', 'count_rabota_average_lag', 'count_unistream_kyrgyzstan_sum_lag', 'count_unistream_kyrgyzstan_average_lag', 'count_unistream_sum_lag', 'count_unistream_average_lag', 'count_vakancii_sum_lag', 'count_vakancii_average_lag', 'count_zarplata_sum_lag', 'count_zarplata_average_lag', 'count_zolotaya_korona_kyrgyzstan_sum_lag', 'count_zolotaya_korona_kyrgyzstan_average_lag', 'count_zolotaya_korona_sum_lag', 'count_zolotaya_korona_average_lag', 'pct_ailyk_average_lag', 'pct_aviabilet_bishkek_average_lag', 'pct_bilet_bishkek_average_lag', 'pct_jumush_izdeim_average_lag', 'pct_jumush_average_lag', 'pct_perevod_deneg_v_kyrgyzstan_average_lag', 'pct_perevod_deneg_average_lag', 'pct_poisk_raboty_average_lag', 'pct_rabota_average_lag', 'pct_unistream_kyrgyzstan_average_lag', 'pct_unistream_average_lag', 'pct_vakancii_average_lag', 'pct_zarplata_average_lag', 'pct_zolotaya_korona_kyrgyzstan_average_lag', 'pct_zolotaya_korona_average_lag', 'ratio_work_lag', 'ratio_job_search_lag', 'ratio_money_transfer_lag', 'ratio_unistr ...

# %%
# NA handling

# Check for NaN values in each column and count the number of missing values per column
missing_counts = X.isna().sum()

# Print columns with missing values and how many missing values in each
print(missing_counts[missing_counts > 0])
print(missing_counts[missing_counts > 1])

# Alternatively, check if a column has "lag" in its name and filter out columns
lag_columns = [col for col in X.columns if 'lag' in col]

# Filter out columns that contain "lag" in their name
X_filtered = X.drop(columns=lag_columns)

# Filter out columns with exactly 1 missing value
X_filtered = X_filtered.loc[:, X_filtered.isna().sum() != 1]

missing_counts = X_filtered.isna().sum()

# Print columns with missing values and how many missing values in each
print(missing_counts[missing_counts > 0])

#Drop the first year so that we don't have to worry about lag NAs
X = X.loc[X["Year"] > 2018]  # Keep only rows after the first year

# Print columns with missing values and how many missing values in each
missing_counts = X.isna().sum()
print(missing_counts[missing_counts > 0])

print(X.describe())
# Out:
# count_ailyk_sum_lag                                 1
# count_ailyk_average_lag                             1
# count_aviabilet_bishkek_sum_lag                     1
# count_aviabilet_bishkek_average_lag                 1
# count_bilet_bishkek_sum_lag                         1
#                                                    ..
# count_zarplata_average_log_lag                      1
# count_zolotaya_korona_kyrgyzstan_sum_log_lag        1
# count_zolotaya_korona_kyrgyzstan_average_log_lag    1
# count_zolotaya_korona_sum_log_lag                   1
# count_zolotaya_korona_average_log_lag               1
# Length: 80, dtype: int64
# Series([], dtype: int64)
# Series([], dtype: int64)
# Series([], dtype: int64)
#               Year  count_ailyk_sum  count_ailyk_average  \
# count   486.000000       486.000000           486.000000
# mean   2021.500000        58.032922             4.836077
# std       1.709585       218.615680            18.217973
# min    2019.000000         0.000000             0.000000
# 25%    2020.000000         2.000000             0.166667
# 50%    2021.500000         7.000000             0.583333
# 75%    2023.000000        18.000000             1.500000
# max    2024.000000      1972.000000           164.333333
#
#        count_aviabilet_bishkek_sum  count_aviabilet_bishkek_average  \
# count                   486.000000                       486.000000
# mean                   4382.331276                       365.194273
# std                   15552.282437                      1296.023536
# min                      21.000000                         1.750000
# 25%                     403.250000                        33.604167
# 50%                    1131.000000                        94.250000
# 75%                    2655.500000                       221.291667
# max                  208054.000000                     17337.833333
#
#        count_bilet_bishkek_sum  count_bilet_bishkek_average  \
# count               486.000000                   486.000000
# mean               3333.125514                   277.760460
# std               11917.012407                   993.084367
# min                  17.000000                     1.416667
# 25%                 344.250000                    28.687500
# 50%                 887.000000                    73.916667
# 75%                2158.750000                   179.895833
# max              158874.000000                 13239.500000
#
#        count_jumush_izdeim_sum  count_jumush_izdeim_average  count_jumush_sum  \
# count               486.000000                   486.000000        486.000000
# mean                 44.458848                     3.704904       3928.705761
# std                 501.593339                    41.799445      38742.530640
# min                   0.000000                     0.000000          0.000000
# 25%                   0.000000                     0.000000         12.250000
# 50%                   0.000000                     0.000000         34.000000
# 75%                   1.750000                     0.145833        116.500000
# max                9962.000000                   830.166667     646459.000000
#
#        ...  count_unistream_sum_log_lag  count_unistream_average_log_lag  \
# count  ...                   486.000000                       486.000000
# mean   ...                     7.899040                         5.424506
# std    ...                     1.443578                         1.430459
# min    ...                     4.219508                         1.884541
# 25%    ...                     7.014138                         4.539073
# 50%    ...                     7.868061                         5.387356
# 75%    ...                     8.743412                         6.260258
# max    ...                    12.993325                        10.508443
#
#        count_vakancii_sum_log_lag  count_vakancii_average_log_lag  \
# count                  486.000000                      486.000000
# mean                    14.165530                       11.680641
# std                      1.233954                        1.233931
# min                     10.778790                        8.294112
# 25%                     13.610859                       11.125965
# 50%                     14.265479                       11.780579
# 75%                     14.888460                       12.403557
# max                     17.584054                       15.099147
#
#        count_zarplata_sum_log_lag  count_zarplata_average_log_lag  \
# count                  486.000000                      486.000000
# mean                    12.575214                       10.090377
# std                      1.097597                        1.097522
# min                      9.663897                        7.179689
# 25%                     11.974644                        9.489807
# 50%                     12.545520                       10.060653
# 75%                     13.326394                       10.841505
# max                     15.824473                       13.339568
#
#        count_zolotaya_korona_kyrgyzstan_sum_log_lag  \
# count                                    486.000000
# mean                                       2.125391
# std                                        1.381858
# min                                        0.000000
# 25%                                        1.098612
# 50%                                        2.079442
# 75%                                        2.890372
# max                                        7.478170
#
#        count_zolotaya_korona_kyrgyzstan_average_log_lag  \
# count                                        486.000000
# mean                                           0.674963
# std                                            0.758728
# min                                            0.000000
# 25%                                            0.154151
# 50%                                            0.459532
# 75%                                            0.882389
# max                                            4.999462
#
#        count_zolotaya_korona_sum_log_lag  \
# count                         486.000000
# mean                            9.392274
# std                             1.255324
# min                             6.317165
# 25%                             8.601075
# 50%                             9.304149
# 75%                            10.092638
# max                            14.023597
#
#        count_zolotaya_korona_average_log_lag
# count                             486.000000
# mean                                6.909208
# std                                 1.253360
# min                                 3.851919
# 25%                                 6.118189
# 50%                                 6.820243
# 75%                                 7.608186
# max                                11.538699
#
# [8 rows x 161 columns]

# %%
# Get a region matrix
region_year_copy = X[['Region', 'Year']].copy()

# %%
# One-hot encode the "Region" column in X
X = pd.get_dummies(X, columns=['Region'], drop_first=False, dtype=int)

#print(X.head())

# %%
# Split data
X_train = X[X["Year"].isin([2021, 2022])].drop(columns=["Year"])
y_Inflow_train = y_Inflow.loc[X_train.index]  # Use X_train's index
y_Outflow_train = y_Outflow.loc[X_train.index]
y_Netflow_train = y_Netflow.loc[X_train.index]

X_val = X[X["Year"] == 2023].drop(columns=["Year"])
y_Inflow_val = y_Inflow.loc[X_val.index]  # Use X_val's index
y_Outflow_val = y_Outflow.loc[X_val.index]
y_Netflow_val = y_Netflow.loc[X_val.index]


# Display summary
print("X_train shape:", X_train.shape)
print("y_train shape:", y_Inflow_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_Inflow_val.shape)

#print(X_train.head())
#print(y_Inflow_train.head())
# Out:
# X_train shape: (162, 241)
# y_train shape: (162,)
# X_val shape: (81, 241)
# y_val shape: (81,)

# %%
# Scale numeric features
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# 1) For X_train
dummies = X_train.loc[:, (X_train.max() == 1) & (X_train.min() == 0)]
X_train_continuous = X_train.drop(columns=dummies.columns)
X_train_scaled = scaler.fit_transform(X_train_continuous)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_continuous.columns, index=X_train_continuous.index)
X_train_scaled = pd.concat([X_train_scaled, dummies], axis=1)

#print("Columns being transformed (continuous variables):")
#print(X_train_continuous.columns.tolist())
#print("\nColumns NOT being transformed (binary/categorical variables):")
#print(dummies.columns.tolist())

# 2) For X_val
dummies = X_val.loc[:, (X_val.max() == 1) & (X_val.min() == 0)]
X_val_continuous = X_val.drop(columns=dummies.columns)
X_val_scaled = scaler.transform(X_val_continuous)  # Use transform only
X_val_scaled = pd.DataFrame(X_val_scaled, columns=X_val_continuous.columns, index=X_val_continuous.index)
X_val_scaled = pd.concat([X_val_scaled, dummies], axis=1)

#print("Columns being transformed (continuous variables):")
#print(X_val_continuous.columns.tolist())
#print("\nColumns NOT being transformed (binary/categorical variables):")
#print(dummies.columns.tolist())

# 3) For X
# Check if 'Year' column is in X
if 'Year' in X.columns:
    print("Yes, 'Year' is in X.")
else:
    print("No, 'Year' is not in X.")

dummies = X.loc[:, (X.max() == 1) & (X.min() == 0)]
# Add the "Year" column to the dummies DataFrame for processing purposes
dummies = pd.concat([dummies, X['Year']], axis=1)
X_continuous = X.drop(columns=dummies.columns)
X_scaled = scaler.transform(X_continuous)
X_scaled = pd.DataFrame(X_scaled, columns=X_continuous.columns, index=X_continuous.index)
X_scaled = pd.concat([X_scaled, dummies], axis=1)

#print("Columns being transformed (continuous variables):")
#print(X_continuous.columns.tolist())
#print("\nColumns NOT being transformed (binary/categorical variables):")
#print(dummies.columns.tolist())

# Display the result
#print(X_val_scaled.head(5))
#print(X_train_scaled.head(5))
#print(X_scaled.head(5))

#print(X_train_scaled.describe())

# Standardize the target variable
yscaler = StandardScaler()
y_Inflow_train_scaled = yscaler.fit_transform(y_Inflow_train.values.reshape(-1, 1)).ravel()
y_Inflow_val_scaled = yscaler.transform(y_Inflow_val.values.reshape(-1, 1)).ravel()
y_Inflow_scaled = yscaler.transform(y_Inflow.values.reshape(-1, 1)).ravel()

outyscaler = StandardScaler()
y_Outflow_train_scaled = outyscaler.fit_transform(y_Outflow_train.values.reshape(-1, 1)).ravel()
y_Outflow_val_scaled = outyscaler.transform(y_Outflow_val.values.reshape(-1, 1)).ravel()
y_Outflow_scaled = outyscaler.transform(y_Outflow.values.reshape(-1, 1)).ravel()

netyscaler = StandardScaler()
y_Netflow_train_scaled = netyscaler.fit_transform(y_Netflow_train.values.reshape(-1, 1)).ravel()
y_Netflow_val_scaled = netyscaler.transform(y_Netflow_val.values.reshape(-1, 1)).ravel()
y_Netflow_scaled = netyscaler.transform(y_Netflow.values.reshape(-1, 1)).ravel()
# Out:
# Yes, 'Year' is in X.

# %%
#Create combination sets (Train+Val) for model training at the end

X_trainPLUSval = pd.concat([X_train, X_val], axis=0)
# X_scaled (scaled data)
X_trainPLUSval_scaled = pd.concat([X_train_scaled, X_val_scaled], axis=0)

# 2) Combine target variables for the training and validation sets
y_Inflow_trainPLUSval_scaled = pd.concat(
    [pd.Series(y_Inflow_train_scaled), pd.Series(y_Inflow_val_scaled)], axis=0
)

y_Outflow_trainPLUSval_scaled = pd.concat(
    [pd.Series(y_Outflow_train_scaled), pd.Series(y_Outflow_val_scaled)], axis=0
)

y_Netflow_trainPLUSval_scaled = pd.concat(
    [pd.Series(y_Netflow_train_scaled), pd.Series(y_Netflow_val_scaled)], axis=0
)

y_Inflow_trainPLUSval = pd.concat(
    [pd.Series(y_Inflow_train), pd.Series(y_Inflow_val)], axis=0
)

y_Outflow_trainPLUSval = pd.concat(
    [pd.Series(y_Outflow_train), pd.Series(y_Outflow_val)], axis=0
)

y_Netflow_trainPLUSval = pd.concat(
    [pd.Series(y_Netflow_train), pd.Series(y_Netflow_val)], axis=0
)

# %%
# 1) Dimensions for the full dataset (2017-2024)
print("Full dataset (2017-2024) dimensions:")
print("X shape:", X.shape)
print("X_scaled shape:", X_scaled.shape)

# 2) Dimensions for the training set (2021-2022)
print("\nTraining set (2021-2022) dimensions:")
print("X_train shape:", X_train.shape)
print("X_train_scaled shape:", X_train_scaled.shape)
print("y_Inflow_train shape:", y_Inflow_train.shape)
print("y_Inflow_trainPLUSval shape:", y_Inflow_train_scaled.shape)
print("y_Outflow_train shape:", y_Outflow_train.shape)
print("y_Netflow_train shape:", y_Netflow_train.shape)

# 3) Dimensions for the validation set (2023)
print("\nValidation set (2023) dimensions:")
print("X_val shape:", X_val.shape)
print("X_val_scaled shape:", X_val_scaled.shape)
print("y_Inflow_trainPLUSval shape:", y_Inflow_val_scaled.shape)
print("y_Inflow_val shape:", y_Inflow_val.shape)
print("y_Outflow_val shape:", y_Outflow_val.shape)
print("y_Netflow_val shape:", y_Inflow_val.shape)

# 4) Dimensions for the combined train and validation set (2021-2023)
print("\nTrain+Val set (2021-2023) dimensions:")
print("X_trainPLUSval shape:", X_trainPLUSval.shape)
print("X_trainPLUSval_scaled shape:", X_trainPLUSval_scaled.shape)
print("y_Inflow_trainPLUSval_scaled shape:", y_Inflow_trainPLUSval_scaled.shape)
print("y_Outflow_trainPLUSval_scaled shape:", y_Outflow_trainPLUSval_scaled.shape)
print("y_Netflow_trainPLUSval_scaled shape:", y_Netflow_trainPLUSval_scaled.shape)
# Out:
# Full dataset (2017-2024) dimensions:
# X shape: (486, 242)
# X_scaled shape: (486, 242)
#
# Training set (2021-2022) dimensions:
# X_train shape: (162, 241)
# X_train_scaled shape: (162, 241)
# y_Inflow_train shape: (162,)
# y_Inflow_trainPLUSval shape: (162,)
# y_Outflow_train shape: (162,)
# y_Netflow_train shape: (162,)
#
# Validation set (2023) dimensions:
# X_val shape: (81, 241)
# X_val_scaled shape: (81, 241)
# y_Inflow_trainPLUSval shape: (81,)
# y_Inflow_val shape: (81,)
# y_Outflow_val shape: (81,)
# y_Netflow_val shape: (81,)
#
# Train+Val set (2021-2023) dimensions:
# X_trainPLUSval shape: (243, 241)
# X_trainPLUSval_scaled shape: (243, 241)
# y_Inflow_trainPLUSval_scaled shape: (243,)
# y_Outflow_trainPLUSval_scaled shape: (243,)
# y_Netflow_trainPLUSval_scaled shape: (243,)

# %% [markdown]
# Now we have data readily available for the following:
#
# - X, X_scaled (full set 2017-2024)
#
# - X_train, X_train_scaled (training set: 2021-22)
# - y_Inflow_train, y_Outflow_train, y_Netflow_train (training set: 2021-22)
#
# - X_val, X_val_scaled (validation set: 2023)
# - y_Inflow_val, y_Outflow_val, y_Netflow_val (validation set: 2023)
#
# - X_trainPLUSval, X_trainPLUSval_scaled (for training at the end! 2021-23)
# - y_Inflow_trainPLUSval, y_Outflow_trainPLUSval, y_Netflow_trainPLUSval (2021-23)

# %% [markdown]
# ### Selecting the right model for prediction
#
# Candidates:
# - XGBoost
# - Stochastic gradient descent (including elastic net spec)
# - Random forest
# - Neural network
# - Elastic net
#
# We will get confidence intervals after choosing the highest accuracy model, since the point estimate is the most important component here.

# %%
# Packages
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
#!brew install libomp 
#!pip install --force-reinstall xgboost
import xgboost
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import RandomizedSearchCV
import time
from sklearn.metrics import mean_squared_error, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve

# %%
# Tuning I

# Define a function to fit and tune models
def tune_model(model, param_grid, X_train, y_train):
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=1)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, grid_search.best_params_

# Define hyperparameter grids for each model
param_grids = {
    'NeuralNetwork': {
        'hidden_layer_sizes': [(10,), (25,), (50,), (75,), (100,), 
                               (10,10), (25,10), (50,20), (75,30), 
                               (100,40), (50, 50), (100, 50), (100, 100)],
        'activation': ['relu', 'tanh'],
        'solver': ['adam'],
        'learning_rate': ['constant', 'adaptive'],
        'learning_rate_init': [0.001, 0.01, 0.1, 0.2],
        'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 5],
        'early_stopping': [True, False],
        'momentum': [0.9, 0.95, 0.99],
        'max_iter': [1500, 2500, 5000]
    },
    'XGBoost': {
        'learning_rate': [0.01, 0.1, 0.3],
        'n_estimators': [50, 100, 200],
        'max_depth': [2, 3, 5, 7],
        'subsample': [1.0],
        'colsample_bytree': [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 
                             0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7,
                             0.75, 0.8],
        'gamma': [0, 0.1, 0.3, 0.5],
        'alpha': [0, 0.1, 0.3, 0.5],  
        'lambda': [0, 0.1, 0.3, 0.5]  
    },
    'SGD': {
        'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
        'max_iter': [1000, 1500],
        'penalty': ['l2', 'elasticnet', 'l1'],
        'tol': [1e-3, 1e-4],
        'learning_rate': ['constant', 'invscaling', 'adaptive'],
        'fit_intercept': [True],
        'power_t': [0.5, 0.6, 0.8]
    },
    'RandomForest': {
        'n_estimators': [100, 200, 300, 500],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 7],
        'min_samples_leaf': [1, 2, 3, 5],
        'bootstrap': [True],
        'max_features': [None, 'sqrt', 'log2', 5, 10, 20, 30, 50, 100],
        'min_impurity_decrease': [0.0, 0.1, 0.2]
    },
    'ElasticNet': {
        'alpha': [0, 0.01, 0.1, 0.25, 0.5, 0.75,
                  1.0, 1.5, 2, 3, 4, 5, 6, 7, 8, 9, 10],
        'l1_ratio': [0.2, 0.5, 0.8],
        'max_iter': [1000, 2000, 3000],
        'fit_intercept': [True],
        'selection': ['cyclic', 'random'], 
        'tol': [1e-4, 1e-5]
    }
}

# Define models for the pipeline
models = {
    'NeuralNetwork': MLPRegressor(),
    'XGBoost': xgboost.XGBRegressor(),
    'SGD': SGDRegressor(),
    'RandomForest': RandomForestRegressor(),
    'ElasticNet': ElasticNet(),
}

#Needs a numpy array
X_trainPLUSval_scaled_np = X_trainPLUSval_scaled.to_numpy()
y_Outflow_trainPLUSval_np = y_Outflow_trainPLUSval_scaled.to_numpy()

print(y_Outflow_trainPLUSval_scaled)
print(y_Outflow_trainPLUSval_scaled.isnull().sum())  # Check for missing values
# Out:
# 0    -0.357486
# 1    -0.192245
# 2    -0.441775
# 3    -0.368335
# 4    -0.377515
#         ...
# 76   -0.294060
# 77   -0.268189
# 78   -0.284880
# 79   -0.411731
# 80   -0.423415
# Length: 243, dtype: float64
# 0

# %%
# Tuning III: what if we standardize the y too? 

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid

# Function to tune models automatically over the parameter grid
def tune_all_models(models, param_grids, X_train, y_train, X_val, y_val):
    model_results = {}  # Dictionary to store results for all models

    for model_name, model in models.items():
        print(f"Starting tuning for {model_name}...")

        # Get the parameter grid for the model
        param_grid = param_grids.get(model_name, {})
        if not param_grid:
            print(f"No parameter grid found for {model_name}, skipping model.")
            continue

        # Initialize list to store the results for the current model
        results = []
        i = 0

        # Iterate over all parameter combinations
        for params in ParameterGrid(param_grid):  # Using ParameterGrid to iterate over combinations
            model.set_params(**params)  # Set model parameters

            # Fit the model
            model.fit(X_train_scaled, y_Outflow_train_scaled)

            # Make predictions on the validation set
            y_pred = model.predict(X_val)

            # Calculate the mean squared error
            mse = mean_squared_error(y_Outflow_val_scaled, y_pred)

            # Store the result with the parameter combination
            results.append({'params': params, 'mse': mse})

            i += 1
            if i % 50 == 0:
                print(f"Trained fit {i}/{len(ParameterGrid(param_grid))} for {model_name}. Moving to next.")

        print(f"Finished tuning for {model_name}.")

        # Get the best result (the one with the lowest MSE)
        best_result = min(results, key=lambda x: x['mse'])
        best_params = best_result['params']
        best_mse = best_result['mse']

        # Store the results for the current model
        model_results[model_name] = {
            'best_params': best_params,
            'best_val_mse': best_mse,
            'all_results': results
        }

        print(f"Best Parameters for {model_name}: {best_params}")
        print(f"Best Validation MSE for {model_name}: {best_mse:.4f}\n")

    return model_results

# Example usage: Tuning all models
model_results = tune_all_models(models, param_grids, X_train_scaled, y_Outflow_train_scaled, X_val_scaled, y_Outflow_val_scaled)

# Print out the results for all models
print("Final Results for All Models:")
for model_name, result in model_results.items():
    print(f"{model_name} - Best Params: {result['best_params']}, Best Validation MSE: {result['best_val_mse']:.4f}")
# Out:
# Starting tuning for NeuralNetwork...
# Trained fit 50/22464 for NeuralNetwork. Moving to next.
# Trained fit 100/22464 for NeuralNetwork. Moving to next.
# Trained fit 150/22464 for NeuralNetwork. Moving to next.
# Trained fit 200/22464 for NeuralNetwork. Moving to next.
# Trained fit 250/22464 for NeuralNetwork. Moving to next.
# Trained fit 300/22464 for NeuralNetwork. Moving to next.
# Trained fit 350/22464 for NeuralNetwork. Moving to next.
# Trained fit 400/22464 for NeuralNetwork. Moving to next.
# Trained fit 450/22464 for NeuralNetwork. Moving to next.
# Trained fit 500/22464 for NeuralNetwork. Moving to next.
# Trained fit 550/22464 for NeuralNetwork. Moving to next.
# Trained fit 600/22464 for NeuralNetwork. Moving to next.
# Trained fit 650/22464 for NeuralNetwork. Moving to next.
# Trained fit 700/22464 for NeuralNetwork. Moving to next.
# Trained fit 750/22464 for NeuralNetwork. Moving to next.
# Trained fit 800/22464 for NeuralNetwork. Moving to next.
# Trained fit 850/22464 for NeuralNetwork. Moving to next.
# Trained fit 900/22464 for NeuralNetwork. Moving to next.
# Trained fit 950/22464 for NeuralNetwork. Moving to next.
# Trained fit 1000/22464 for NeuralNetwork. Moving to next.
# Trained fit 1050/22464 for NeuralNetwork. Moving to next.
# Trained fit 1100/22464 for NeuralNetwork. Moving to next.
# Trained fit 1150/22464 for NeuralNetwork. Moving to next.
# Trained fit 1200/22464 for NeuralNetwork. Moving to next.
# Trained fit 1250/22464 for NeuralNetwork. Moving to next.
# Trained fit 1300/22464 for NeuralNetwork. Moving to next.
# Trained fit 1350/22464 for NeuralNetwork. Moving to next.
# Trained fit 1400/22464 for NeuralNetwork. Moving to next.
# Trained fit 1450/22464 for NeuralNetwork. Moving to next.
# Trained fit 1500/22464 for NeuralNetwork. Moving to next.
# Trained fit 1550/22464 for NeuralNetwork. Moving to next.
# Trained fit 1600/22464 for NeuralNetwork. Moving to next.
# Trained fit 1650/22464 for NeuralNetwork. Moving to next.
# Trained fit 1700/22464 for NeuralNetwork. Moving to next.
# Trained fit 1750/22464 for NeuralNetwork. Moving to next.
# Trained fit 1800/22464 for NeuralNetwork. Moving to next.
# Trained fit 1850/22464 for NeuralNetwork. Moving to next.
# Trained fit 1900/22464 for NeuralNetwork. Moving to next.
# Trained fit 1950/22464 for NeuralNetwork. Moving to next.
# Trained fit 2000/22464 for NeuralNetwork. Moving to next.
# Trained fit 2050/22464 for NeuralNetwork. Moving to next.
# Trained fit 2100/22464 for NeuralNetwork. Moving to next.
# Trained fit 2150/22464 for NeuralNetwork. Moving to next.
# Trained fit 2200/22464 for NeuralNetwork. Moving to next.
# Trained fit 2250/22464 for NeuralNetwork. Moving to next.
# Trained fit 2300/22464 for NeuralNetwork. Moving to next.
# Trained fit 2350/22464 for NeuralNetwork. Moving to next.
# Trained fit 2400/22464 for NeuralNetwork. Moving to next.
# Trained fit 2450/22464 for NeuralNetwork. Moving to next.
# Trained fit 2500/22464 for NeuralNetwork. Moving to next.
# Trained fit 2550/22464 for NeuralNetwork. Moving to next.
# Trained fit 2600/22464 for NeuralNetwork. Moving to next.
# Trained fit 2650/22464 for NeuralNetwork. Moving to next.
# Trained fit 2700/22464 for NeuralNetwork. Moving to next.
# Trained fit 2750/22464 for NeuralNetwork. Moving to next.
# Trained fit 2800/22464 for NeuralNetwork. Moving to next.
# Trained fit 2850/22464 for NeuralNetwork. Moving to next.
# Trained fit 2900/22464 for NeuralNetwork. Moving to next.
# Trained fit 2950/22464 for NeuralNetwork. Moving to next.
# Trained fit 3000/22464 for NeuralNetwork. Moving to next.
# Trained fit 3050/22464 for NeuralNetwork. Moving to next.
# Trained fit 3100/22464 for NeuralNetwork. Moving to next.
# Trained fit 3150/22464 for NeuralNetwork. Moving to next.
# Trained fit 3200/22464 for NeuralNetwork. Moving to next.
# Trained fit 3250/22464 for NeuralNetwork. Moving to next.
# Trained fit 3300/22464 for NeuralNetwork. Moving to next.
# Trained fit 3350/22464 for NeuralNetwork. Moving to next.
# Trained fit 3400/22464 for NeuralNetwork. Moving to next.
# Trained fit 3450/22464 for NeuralNetwork. Moving to next.
# Trained fit 3500/22464 for NeuralNetwork. Moving to next.
# Trained fit 3550/22464 for NeuralNetwork. Moving to next.
# Trained fit 3600/22464 for NeuralNetwork. Moving to next.
# Trained fit 3650/22464 for NeuralNetwork. Moving to next.
# Trained fit 3700/22464 for NeuralNetwork. Moving to next.
# Trained fit 3750/22464 for NeuralNetwork. Moving to next.
# Trained fit 3800/22464 for NeuralNetwork. Moving to next.
# Trained fit 3850/22464 for NeuralNetwork. Moving to next.
# Trained fit 3900/22464 for NeuralNetwork. Moving to next.
# Trained fit 3950/22464 for NeuralNetwork. Moving to next.
# Trained fit 4000/22464 for NeuralNetwork. Moving to next.
# Trained fit 4050/22464 for NeuralNetwork. Moving to next.
# Trained fit 4100/22464 for NeuralNetwork. Moving to next.
# Trained fit 4150/22464 for NeuralNetwork. Moving to next.
# Trained fit 4200/22464 for NeuralNetwork. Moving to next.
# Trained fit 4250/22464 for NeuralNetwork. Moving to next.
# Trained fit 4300/22464 for NeuralNetwork. Moving to next.
# Trained fit 4350/22464 for NeuralNetwork. Moving to next.
# Trained fit 4400/22464 for NeuralNetwork. Moving to next.
# Trained fit 4450/22464 for NeuralNetwork. Moving to next.
# Trained fit 4500/22464 for NeuralNetwork. Moving to next.
# Trained fit 4550/22464 for NeuralNetwork. Moving to next.
# Trained fit 4600/22464 for NeuralNetwork. Moving to next.
# Trained fit 4650/22464 for NeuralNetwork. Moving to next.
# Trained fit 4700/22464 for NeuralNetwork. Moving to next.
# Trained fit 4750/22464 for NeuralNetwork. Moving to next.
# Trained fit 4800/22464 for NeuralNetwork. Moving to next.
# Trained fit 4850/22464 for NeuralNetwork. Moving to next.
# Trained fit 4900/22464 for NeuralNetwork. Moving to next.
# Trained fit 4950/22464 for NeuralNetwork. Moving to next.
# Trained fit 5000/22464 for NeuralNetwork. Moving to next.
# Trained fit 5050/22464 for NeuralNetwork. Moving to next.
# Trained fit 5100/22464 for NeuralNetwork. Moving to next.
# Trained fit 5150/22464 for NeuralNetwork. Moving to next.
# Trained fit 5200/22464 for NeuralNetwork. Moving to next.
# Trained fit 5250/22464 for NeuralNetwork. Moving to next.
# Trained fit 5300/22464 for NeuralNetwork. Moving to next.
# Trained fit 5350/22464 for NeuralNetwork. Moving to next.
# Trained fit 5400/22464 for NeuralNetwork. Moving to next.
# Trained fit 5450/22464 for NeuralNetwork. Moving to next.
# Trained fit 5500/22464 for NeuralNetwork. Moving to next.
# Trained fit 5550/22464 for NeuralNetwork. Moving to next.
# Trained fit 5600/22464 for NeuralNetwork. Moving to next.
# Trained fit 5650/22464 for NeuralNetwork. Moving to next.
# Trained fit 5700/22464 for NeuralNetwork. Moving to next.
# Trained fit 5750/22464 for NeuralNetwork. Moving to next.
# Trained fit 5800/22464 for NeuralNetwork. Moving to next.
# Trained fit 5850/22464 for NeuralNetwork. Moving to next.
# Trained fit 5900/22464 for NeuralNetwork. Moving to next.
# Trained fit 5950/22464 for NeuralNetwork. Moving to next.
# Trained fit 6000/22464 for NeuralNetwork. Moving to next.
# Trained fit 6050/22464 for NeuralNetwork. Moving to next.
# Trained fit 6100/22464 for NeuralNetwork. Moving to next.
# Trained fit 6150/22464 for NeuralNetwork. Moving to next.
# Trained fit 6200/22464 for NeuralNetwork. Moving to next.
# Trained fit 6250/22464 for NeuralNetwork. Moving to next.
# Trained fit 6300/22464 for NeuralNetwork. Moving to next.
# Trained fit 6350/22464 for NeuralNetwork. Moving to next.
# Trained fit 6400/22464 for NeuralNetwork. Moving to next.
# Trained fit 6450/22464 for NeuralNetwork. Moving to next.
# Trained fit 6500/22464 for NeuralNetwork. Moving to next.
# Trained fit 6550/22464 for NeuralNetwork. Moving to next.
# Trained fit 6600/22464 for NeuralNetwork. Moving to next.
# Trained fit 6650/22464 for NeuralNetwork. Moving to next.
# Trained fit 6700/22464 for NeuralNetwork. Moving to next.
# Trained fit 6750/22464 for NeuralNetwork. Moving to next.
# Trained fit 6800/22464 for NeuralNetwork. Moving to next.
# Trained fit 6850/22464 for NeuralNetwork. Moving to next.
# Trained fit 6900/22464 for NeuralNetwork. Moving to next.
# Trained fit 6950/22464 for NeuralNetwork. Moving to next.
# Trained fit 7000/22464 for NeuralNetwork. Moving to next.
# Trained fit 7050/22464 for NeuralNetwork. Moving to next.
# Trained fit 7100/22464 for NeuralNetwork. Moving to next.
# Trained fit 7150/22464 for NeuralNetwork. Moving to next.
# Trained fit 7200/22464 for NeuralNetwork. Moving to next.
# Trained fit 7250/22464 for NeuralNetwork. Moving to next.
# Trained fit 7300/22464 for NeuralNetwork. Moving to next.
# Trained fit 7350/22464 for NeuralNetwork. Moving to next.
# Trained fit 7400/22464 for NeuralNetwork. Moving to next.
# Trained fit 7450/22464 for NeuralNetwork. Moving to next.
# Trained fit 7500/22464 for NeuralNetwork. Moving to next.
# Trained fit 7550/22464 for NeuralNetwork. Moving to next.
# Trained fit 7600/22464 for NeuralNetwork. Moving to next.
# Trained fit 7650/22464 for NeuralNetwork. Moving to next.
# Trained fit 7700/22464 for NeuralNetwork. Moving to next.
# Trained fit 7750/22464 for NeuralNetwork. Moving to next.
# Trained fit 7800/22464 for NeuralNetwork. Moving to next.
# Trained fit 7850/22464 for NeuralNetwork. Moving to next.
# Trained fit 7900/22464 for NeuralNetwork. Moving to next.
# Trained fit 7950/22464 for NeuralNetwork. Moving to next.
# Trained fit 8000/22464 for NeuralNetwork. Moving to next.
# Trained fit 8050/22464 for NeuralNetwork. Moving to next.
# Trained fit 8100/22464 for NeuralNetwork. Moving to next.
# Trained fit 8150/22464 for NeuralNetwork. Moving to next.
# Trained fit 8200/22464 for NeuralNetwork. Moving to next.
# Trained fit 8250/22464 for NeuralNetwork. Moving to next.
# Trained fit 8300/22464 for NeuralNetwork. Moving to next.
# Trained fit 8350/22464 for NeuralNetwork. Moving to next.
# Trained fit 8400/22464 for NeuralNetwork. Moving to next.
# Trained fit 8450/22464 for NeuralNetwork. Moving to next.
# Trained fit 8500/22464 for NeuralNetwork. Moving to next.
# Trained fit 8550/22464 for NeuralNetwork. Moving to next.
# Trained fit 8600/22464 for NeuralNetwork. Moving to next.
# Trained fit 8650/22464 for NeuralNetwork. Moving to next.
# Trained fit 8700/22464 for NeuralNetwork. Moving to next.
# Trained fit 8750/22464 for NeuralNetwork. Moving to next.
# Trained fit 8800/22464 for NeuralNetwork. Moving to next.
# Trained fit 8850/22464 for NeuralNetwork. Moving to next.
# Trained fit 8900/22464 for NeuralNetwork. Moving to next.
# Trained fit 8950/22464 for NeuralNetwork. Moving to next.
# Trained fit 9000/22464 for NeuralNetwork. Moving to next.
# Trained fit 9050/22464 for NeuralNetwork. Moving to next.
# Trained fit 9100/22464 for NeuralNetwork. Moving to next.
# Trained fit 9150/22464 for NeuralNetwork. Moving to next.
# Trained fit 9200/22464 for NeuralNetwork. Moving to next.
# Trained fit 9250/22464 for NeuralNetwork. Moving to next.
# Trained fit 9300/22464 for NeuralNetwork. Moving to next.
# Trained fit 9350/22464 for NeuralNetwork. Moving to next.
# Trained fit 9400/22464 for NeuralNetwork. Moving to next.
# Trained fit 9450/22464 for NeuralNetwork. Moving to next.
# Trained fit 9500/22464 for NeuralNetwork. Moving to next.
# Trained fit 9550/22464 for NeuralNetwork. Moving to next.
# Trained fit 9600/22464 for NeuralNetwork. Moving to next.
# Trained fit 9650/22464 for NeuralNetwork. Moving to next.
# Trained fit 9700/22464 for NeuralNetwork. Moving to next.
# Trained fit 9750/22464 for NeuralNetwork. Moving to next.
# Trained fit 9800/22464 for NeuralNetwork. Moving to next.
# Trained fit 9850/22464 for NeuralNetwork. Moving to next.
# Trained fit 9900/22464 for NeuralNetwork. Moving to next.
# Trained fit 9950/22464 for NeuralNetwork. Moving to next.
# Trained fit 10000/22464 for NeuralNetwork. Moving to next.
# Trained fit 10050/22464 for NeuralNetwork. Moving to next.
# Trained fit 10100/22464 for NeuralNetwork. Moving to next.
# Trained fit 10150/22464 for NeuralNetwork. Moving to next.
# Trained fit 10200/22464 for NeuralNetwork. Moving to next.
# Trained fit 10250/22464 for NeuralNetwork. Moving to next.
# Trained fit 10300/22464 for NeuralNetwork. Moving to next.
# Trained fit 10350/22464 for NeuralNetwork. Moving to next.
# Trained fit 10400/22464 for NeuralNetwork. Moving to next.
# Trained fit 10450/22464 for NeuralNetwork. Moving to next.
# Trained fit 10500/22464 for NeuralNetwork. Moving to next.
# Trained fit 10550/22464 for NeuralNetwork. Moving to next.
# Trained fit 10600/22464 for NeuralNetwork. Moving to next.
# Trained fit 10650/22464 for NeuralNetwork. Moving to next.
# Trained fit 10700/22464 for NeuralNetwork. Moving to next.
# Trained fit 10750/22464 for NeuralNetwork. Moving to next.
# Trained fit 10800/22464 for NeuralNetwork. Moving to next.
# Trained fit 10850/22464 for NeuralNetwork. Moving to next.
# Trained fit 10900/22464 for NeuralNetwork. Moving to next.
# Trained fit 10950/22464 for NeuralNetwork. Moving to next.
# Trained fit 11000/22464 for NeuralNetwork. Moving to next.
# Trained fit 11050/22464 for NeuralNetwork. Moving to next.
# Trained fit 11100/22464 for NeuralNetwork. Moving to next.
# Trained fit 11150/22464 for NeuralNetwork. Moving to next.
# Trained fit 11200/22464 for NeuralNetwork. Moving to next.
# Trained fit 11250/22464 for NeuralNetwork. Moving to next.
# Trained fit 11300/22464 for NeuralNetwork. Moving to next.
# Trained fit 11350/22464 for NeuralNetwork. Moving to next.
# Trained fit 11400/22464 for NeuralNetwork. Moving to next.
# Trained fit 11450/22464 for NeuralNetwork. Moving to next.
# Trained fit 11500/22464 for NeuralNetwork. Moving to next.
# Trained fit 11550/22464 for NeuralNetwork. Moving to next.
# Trained fit 11600/22464 for NeuralNetwork. Moving to next.
# Trained fit 11650/22464 for NeuralNetwork. Moving to next.
# Trained fit 11700/22464 for NeuralNetwork. Moving to next.
# Trained fit 11750/22464 for NeuralNetwork. Moving to next.
# Trained fit 11800/22464 for NeuralNetwork. Moving to next.
# Trained fit 11850/22464 for NeuralNetwork. Moving to next.
# Trained fit 11900/22464 for NeuralNetwork. Moving to next.
# Trained fit 11950/22464 for NeuralNetwork. Moving to next.
# Trained fit 12000/22464 for NeuralNetwork. Moving to next.
# Trained fit 12050/22464 for NeuralNetwork. Moving to next.
# Trained fit 12100/22464 for NeuralNetwork. Moving to next.
# Trained fit 12150/22464 for NeuralNetwork. Moving to next.
# Trained fit 12200/22464 for NeuralNetwork. Moving to next.
# Trained fit 12250/22464 for NeuralNetwork. Moving to next.
# Trained fit 12300/22464 for NeuralNetwork. Moving to next.
# Trained fit 12350/22464 for NeuralNetwork. Moving to next.
# Trained fit 12400/22464 for NeuralNetwork. Moving to next.
# Trained fit 12450/22464 for NeuralNetwork. Moving to next.
# Trained fit 12500/22464 for NeuralNetwork. Moving to next.
# Trained fit 12550/22464 for NeuralNetwork. Moving to next.
# Trained fit 12600/22464 for NeuralNetwork. Moving to next.
# Trained fit 12650/22464 for NeuralNetwork. Moving to next.
# Trained fit 12700/22464 for NeuralNetwork. Moving to next.
# Trained fit 12750/22464 for NeuralNetwork. Moving to next.
# Trained fit 12800/22464 for NeuralNetwork. Moving to next.
# Trained fit 12850/22464 for NeuralNetwork. Moving to next.
# Trained fit 12900/22464 for NeuralNetwork. Moving to next.
# Trained fit 12950/22464 for NeuralNetwork. Moving to next.
# Trained fit 13000/22464 for NeuralNetwork. Moving to next.
# Trained fit 13050/22464 for NeuralNetwork. Moving to next.
# Trained fit 13100/22464 for NeuralNetwork. Moving to next.
# Trained fit 13150/22464 for NeuralNetwork. Moving to next.
# Trained fit 13200/22464 for NeuralNetwork. Moving to next.
# Trained fit 13250/22464 for NeuralNetwork. Moving to next.
# Trained fit 13300/22464 for NeuralNetwork. Moving to next.
# Trained fit 13350/22464 for NeuralNetwork. Moving to next.
# Trained fit 13400/22464 for NeuralNetwork. Moving to next.
# Trained fit 13450/22464 for NeuralNetwork. Moving to next.
# Trained fit 13500/22464 for NeuralNetwork. Moving to next.
# Trained fit 13550/22464 for NeuralNetwork. Moving to next.
# Trained fit 13600/22464 for NeuralNetwork. Moving to next.
# Trained fit 13650/22464 for NeuralNetwork. Moving to next.
# Trained fit 13700/22464 for NeuralNetwork. Moving to next.
# Trained fit 13750/22464 for NeuralNetwork. Moving to next.
# Trained fit 13800/22464 for NeuralNetwork. Moving to next.
# Trained fit 13850/22464 for NeuralNetwork. Moving to next.
# Trained fit 13900/22464 for NeuralNetwork. Moving to next.
# Trained fit 13950/22464 for NeuralNetwork. Moving to next.
# Trained fit 14000/22464 for NeuralNetwork. Moving to next.
# Trained fit 14050/22464 for NeuralNetwork. Moving to next.
# Trained fit 14100/22464 for NeuralNetwork. Moving to next.
# Trained fit 14150/22464 for NeuralNetwork. Moving to next.
# Trained fit 14200/22464 for NeuralNetwork. Moving to next.
# Trained fit 14250/22464 for NeuralNetwork. Moving to next.
# Trained fit 14300/22464 for NeuralNetwork. Moving to next.
# Trained fit 14350/22464 for NeuralNetwork. Moving to next.
# Trained fit 14400/22464 for NeuralNetwork. Moving to next.
# Trained fit 14450/22464 for NeuralNetwork. Moving to next.
# Trained fit 14500/22464 for NeuralNetwork. Moving to next.
# Trained fit 14550/22464 for NeuralNetwork. Moving to next.
# Trained fit 14600/22464 for NeuralNetwork. Moving to next.
# Trained fit 14650/22464 for NeuralNetwork. Moving to next.
# Trained fit 14700/22464 for NeuralNetwork. Moving to next.
# Trained fit 14750/22464 for NeuralNetwork. Moving to next.
# Trained fit 14800/22464 for NeuralNetwork. Moving to next.
# Trained fit 14850/22464 for NeuralNetwork. Moving to next.
# Trained fit 14900/22464 for NeuralNetwork. Moving to next.
# Trained fit 14950/22464 for NeuralNetwork. Moving to next.
# Trained fit 15000/22464 for NeuralNetwork. Moving to next.
# Trained fit 15050/22464 for NeuralNetwork. Moving to next.
# Trained fit 15100/22464 for NeuralNetwork. Moving to next.
# Trained fit 15150/22464 for NeuralNetwork. Moving to next.
# Trained fit 15200/22464 for NeuralNetwork. Moving to next.
# Trained fit 15250/22464 for NeuralNetwork. Moving to next.
# Trained fit 15300/22464 for NeuralNetwork. Moving to next.
# Trained fit 15350/22464 for NeuralNetwork. Moving to next.
# Trained fit 15400/22464 for NeuralNetwork. Moving to next.
# Trained fit 15450/22464 for NeuralNetwork. Moving to next.
# Trained fit 15500/22464 for NeuralNetwork. Moving to next.
# Trained fit 15550/22464 for NeuralNetwork. Moving to next.
# Trained fit 15600/22464 for NeuralNetwork. Moving to next.
# Trained fit 15650/22464 for NeuralNetwork. Moving to next.
# Trained fit 15700/22464 for NeuralNetwork. Moving to next.
# Trained fit 15750/22464 for NeuralNetwork. Moving to next.
# Trained fit 15800/22464 for NeuralNetwork. Moving to next.
# Trained fit 15850/22464 for NeuralNetwork. Moving to next.
# Trained fit 15900/22464 for NeuralNetwork. Moving to next.
# Trained fit 15950/22464 for NeuralNetwork. Moving to next.
# Trained fit 16000/22464 for NeuralNetwork. Moving to next.
# Trained fit 16050/22464 for NeuralNetwork. Moving to next.
# Trained fit 16100/22464 for NeuralNetwork. Moving to next.
# Trained fit 16150/22464 for NeuralNetwork. Moving to next.
# Trained fit 16200/22464 for NeuralNetwork. Moving to next.
# Trained fit 16250/22464 for NeuralNetwork. Moving to next.
# Trained fit 16300/22464 for NeuralNetwork. Moving to next.
# Trained fit 16350/22464 for NeuralNetwork. Moving to next.
# Trained fit 16400/22464 for NeuralNetwork. Moving to next.
# Trained fit 16450/22464 for NeuralNetwork. Moving to next.
# Trained fit 16500/22464 for NeuralNetwork. Moving to next.
# Trained fit 16550/22464 for NeuralNetwork. Moving to next.
# Trained fit 16600/22464 for NeuralNetwork. Moving to next.
# Trained fit 16650/22464 for NeuralNetwork. Moving to next.
# Trained fit 16700/22464 for NeuralNetwork. Moving to next.
# Trained fit 16750/22464 for NeuralNetwork. Moving to next.
# Trained fit 16800/22464 for NeuralNetwork. Moving to next.
# Trained fit 16850/22464 for NeuralNetwork. Moving to next.
# Trained fit 16900/22464 for NeuralNetwork. Moving to next.
# Trained fit 16950/22464 for NeuralNetwork. Moving to next.
# Trained fit 17000/22464 for NeuralNetwork. Moving to next.
# Trained fit 17050/22464 for NeuralNetwork. Moving to next.
# Trained fit 17100/22464 for NeuralNetwork. Moving to next.
# Trained fit 17150/22464 for NeuralNetwork. Moving to next.
# Trained fit 17200/22464 for NeuralNetwork. Moving to next.
# Trained fit 17250/22464 for NeuralNetwork. Moving to next.
# Trained fit 17300/22464 for NeuralNetwork. Moving to next.
# Trained fit 17350/22464 for NeuralNetwork. Moving to next.
# Trained fit 17400/22464 for NeuralNetwork. Moving to next.
# Trained fit 17450/22464 for NeuralNetwork. Moving to next.
# Trained fit 17500/22464 for NeuralNetwork. Moving to next.
# Trained fit 17550/22464 for NeuralNetwork. Moving to next.
# Trained fit 17600/22464 for NeuralNetwork. Moving to next.
# Trained fit 17650/22464 for NeuralNetwork. Moving to next.
# Trained fit 17700/22464 for NeuralNetwork. Moving to next.
# Trained fit 17750/22464 for NeuralNetwork. Moving to next.
# Trained fit 17800/22464 for NeuralNetwork. Moving to next.
# Trained fit 17850/22464 for NeuralNetwork. Moving to next.
# Trained fit 17900/22464 for NeuralNetwork. Moving to next.
# Trained fit 17950/22464 for NeuralNetwork. Moving to next.
# Trained fit 18000/22464 for NeuralNetwork. Moving to next.
# Trained fit 18050/22464 for NeuralNetwork. Moving to next.
# Trained fit 18100/22464 for NeuralNetwork. Moving to next.
# Trained fit 18150/22464 for NeuralNetwork. Moving to next.
# Trained fit 18200/22464 for NeuralNetwork. Moving to next.
# Trained fit 18250/22464 for NeuralNetwork. Moving to next.
# Trained fit 18300/22464 for NeuralNetwork. Moving to next.
# Trained fit 18350/22464 for NeuralNetwork. Moving to next.
# Trained fit 18400/22464 for NeuralNetwork. Moving to next.
# Trained fit 18450/22464 for NeuralNetwork. Moving to next.
# Trained fit 18500/22464 for NeuralNetwork. Moving to next.
# Trained fit 18550/22464 for NeuralNetwork. Moving to next.
# Trained fit 18600/22464 for NeuralNetwork. Moving to next.
# Trained fit 18650/22464 for NeuralNetwork. Moving to next.
# Trained fit 18700/22464 for NeuralNetwork. Moving to next.
# Trained fit 18750/22464 for NeuralNetwork. Moving to next.
# Trained fit 18800/22464 for NeuralNetwork. Moving to next.
# Trained fit 18850/22464 for NeuralNetwork. Moving to next.
# Trained fit 18900/22464 for NeuralNetwork. Moving to next.
# Trained fit 18950/22464 for NeuralNetwork. Moving to next.
# Trained fit 19000/22464 for NeuralNetwork. Moving to next.
# Trained fit 19050/22464 for NeuralNetwork. Moving to next.
# Trained fit 19100/22464 for NeuralNetwork. Moving to next.
# Trained fit 19150/22464 for NeuralNetwork. Moving to next.
# Trained fit 19200/22464 for NeuralNetwork. Moving to next.
# Trained fit 19250/22464 for NeuralNetwork. Moving to next.
# Trained fit 19300/22464 for NeuralNetwork. Moving to next.
# Trained fit 19350/22464 for NeuralNetwork. Moving to next.
# Trained fit 19400/22464 for NeuralNetwork. Moving to next.
# Trained fit 19450/22464 for NeuralNetwork. Moving to next.
# Trained fit 19500/22464 for NeuralNetwork. Moving to next.
# Trained fit 19550/22464 for NeuralNetwork. Moving to next.
# Trained fit 19600/22464 for NeuralNetwork. Moving to next.
# Trained fit 19650/22464 for NeuralNetwork. Moving to next.
# Trained fit 19700/22464 for NeuralNetwork. Moving to next.
# Trained fit 19750/22464 for NeuralNetwork. Moving to next.
# Trained fit 19800/22464 for NeuralNetwork. Moving to next.
# Trained fit 19850/22464 for NeuralNetwork. Moving to next.
# Trained fit 19900/22464 for NeuralNetwork. Moving to next.
# Trained fit 19950/22464 for NeuralNetwork. Moving to next.
# Trained fit 20000/22464 for NeuralNetwork. Moving to next.
# Trained fit 20050/22464 for NeuralNetwork. Moving to next.
# Trained fit 20100/22464 for NeuralNetwork. Moving to next.
# Trained fit 20150/22464 for NeuralNetwork. Moving to next.
# Trained fit 20200/22464 for NeuralNetwork. Moving to next.
# Trained fit 20250/22464 for NeuralNetwork. Moving to next.
# Trained fit 20300/22464 for NeuralNetwork. Moving to next.
# Trained fit 20350/22464 for NeuralNetwork. Moving to next.
# Trained fit 20400/22464 for NeuralNetwork. Moving to next.
# Trained fit 20450/22464 for NeuralNetwork. Moving to next.
# Trained fit 20500/22464 for NeuralNetwork. Moving to next.
# Trained fit 20550/22464 for NeuralNetwork. Moving to next.
# Trained fit 20600/22464 for NeuralNetwork. Moving to next.
# Trained fit 20650/22464 for NeuralNetwork. Moving to next.
# Trained fit 20700/22464 for NeuralNetwork. Moving to next.
# Trained fit 20750/22464 for NeuralNetwork. Moving to next.
# Trained fit 20800/22464 for NeuralNetwork. Moving to next.
# Trained fit 20850/22464 for NeuralNetwork. Moving to next.
# Trained fit 20900/22464 for NeuralNetwork. Moving to next.
# Trained fit 20950/22464 for NeuralNetwork. Moving to next.
# Trained fit 21000/22464 for NeuralNetwork. Moving to next.
# Trained fit 21050/22464 for NeuralNetwork. Moving to next.
# Trained fit 21100/22464 for NeuralNetwork. Moving to next.
# Trained fit 21150/22464 for NeuralNetwork. Moving to next.
# Trained fit 21200/22464 for NeuralNetwork. Moving to next.
# Trained fit 21250/22464 for NeuralNetwork. Moving to next.
# Trained fit 21300/22464 for NeuralNetwork. Moving to next.
# Trained fit 21350/22464 for NeuralNetwork. Moving to next.
# Trained fit 21400/22464 for NeuralNetwork. Moving to next.
# Trained fit 21450/22464 for NeuralNetwork. Moving to next.
# Trained fit 21500/22464 for NeuralNetwork. Moving to next.
# Trained fit 21550/22464 for NeuralNetwork. Moving to next.
# Trained fit 21600/22464 for NeuralNetwork. Moving to next.
# Trained fit 21650/22464 for NeuralNetwork. Moving to next.
# Trained fit 21700/22464 for NeuralNetwork. Moving to next.
# Trained fit 21750/22464 for NeuralNetwork. Moving to next.
# Trained fit 21800/22464 for NeuralNetwork. Moving to next.
# Trained fit 21850/22464 for NeuralNetwork. Moving to next.
# Trained fit 21900/22464 for NeuralNetwork. Moving to next.
# Trained fit 21950/22464 for NeuralNetwork. Moving to next.
# Trained fit 22000/22464 for NeuralNetwork. Moving to next.
# Trained fit 22050/22464 for NeuralNetwork. Moving to next.
# Trained fit 22100/22464 for NeuralNetwork. Moving to next.
# Trained fit 22150/22464 for NeuralNetwork. Moving to next.
# Trained fit 22200/22464 for NeuralNetwork. Moving to next.
# Trained fit 22250/22464 for NeuralNetwork. Moving to next.
# Trained fit 22300/22464 for NeuralNetwork. Moving to next.
# Trained fit 22350/22464 for NeuralNetwork. Moving to next.
# Trained fit 22400/22464 for NeuralNetwork. Moving to next.
# Trained fit 22450/22464 for NeuralNetwork. Moving to next.
# Finished tuning for NeuralNetwork.
# Best Parameters for NeuralNetwork: {'activation': 'relu', 'alpha': 1, 'early_stopping': True, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1, 'max_iter': 2500, 'momentum': 0.9, 'solver': 'adam'}
# Best Validation MSE for NeuralNetwork: 0.3824
#
# Starting tuning for XGBoost...
# Trained fit 50/34560 for XGBoost. Moving to next.
# Trained fit 100/34560 for XGBoost. Moving to next.
# Trained fit 150/34560 for XGBoost. Moving to next.
# Trained fit 200/34560 for XGBoost. Moving to next.
# Trained fit 250/34560 for XGBoost. Moving to next.
# Trained fit 300/34560 for XGBoost. Moving to next.
# Trained fit 350/34560 for XGBoost. Moving to next.
# Trained fit 400/34560 for XGBoost. Moving to next.
# Trained fit 450/34560 for XGBoost. Moving to next.
# Trained fit 500/34560 for XGBoost. Moving to next.
# Trained fit 550/34560 for XGBoost. Moving to next.
# Trained fit 600/34560 for XGBoost. Moving to next.
# Trained fit 650/34560 for XGBoost. Moving to next.
# Trained fit 700/34560 for XGBoost. Moving to next.
# Trained fit 750/34560 for XGBoost. Moving to next.
# Trained fit 800/34560 for XGBoost. Moving to next.
# Trained fit 850/34560 for XGBoost. Moving to next.
# Trained fit 900/34560 for XGBoost. Moving to next.
# Trained fit 950/34560 for XGBoost. Moving to next.
# Trained fit 1000/34560 for XGBoost. Moving to next.
# Trained fit 1050/34560 for XGBoost. Moving to next.
# Trained fit 1100/34560 for XGBoost. Moving to next.
# Trained fit 1150/34560 for XGBoost. Moving to next.
# Trained fit 1200/34560 for XGBoost. Moving to next.
# Trained fit 1250/34560 for XGBoost. Moving to next.
# Trained fit 1300/34560 for XGBoost. Moving to next.
# Trained fit 1350/34560 for XGBoost. Moving to next.
# Trained fit 1400/34560 for XGBoost. Moving to next.
# Trained fit 1450/34560 for XGBoost. Moving to next.
# Trained fit 1500/34560 for XGBoost. Moving to next.
# Trained fit 1550/34560 for XGBoost. Moving to next.
# Trained fit 1600/34560 for XGBoost. Moving to next.
# Trained fit 1650/34560 for XGBoost. Moving to next.
# Trained fit 1700/34560 for XGBoost. Moving to next.
# Trained fit 1750/34560 for XGBoost. Moving to next.
# Trained fit 1800/34560 for XGBoost. Moving to next.
# Trained fit 1850/34560 for XGBoost. Moving to next.
# Trained fit 1900/34560 for XGBoost. Moving to next.
# Trained fit 1950/34560 for XGBoost. Moving to next.
# Trained fit 2000/34560 for XGBoost. Moving to next.
# Trained fit 2050/34560 for XGBoost. Moving to next.
# Trained fit 2100/34560 for XGBoost. Moving to next.
# Trained fit 2150/34560 for XGBoost. Moving to next.
# Trained fit 2200/34560 for XGBoost. Moving to next.
# Trained fit 2250/34560 for XGBoost. Moving to next.
# Trained fit 2300/34560 for XGBoost. Moving to next.
# Trained fit 2350/34560 for XGBoost. Moving to next.
# Trained fit 2400/34560 for XGBoost. Moving to next.
# Trained fit 2450/34560 for XGBoost. Moving to next.
# Trained fit 2500/34560 for XGBoost. Moving to next.
# Trained fit 2550/34560 for XGBoost. Moving to next.
# Trained fit 2600/34560 for XGBoost. Moving to next.
# Trained fit 2650/34560 for XGBoost. Moving to next.
# Trained fit 2700/34560 for XGBoost. Moving to next.
# Trained fit 2750/34560 for XGBoost. Moving to next.
# Trained fit 2800/34560 for XGBoost. Moving to next.
# Trained fit 2850/34560 for XGBoost. Moving to next.
# Trained fit 2900/34560 for XGBoost. Moving to next.
# Trained fit 2950/34560 for XGBoost. Moving to next.
# Trained fit 3000/34560 for XGBoost. Moving to next.
# Trained fit 3050/34560 for XGBoost. Moving to next.
# Trained fit 3100/34560 for XGBoost. Moving to next.
# Trained fit 3150/34560 for XGBoost. Moving to next.
# Trained fit 3200/34560 for XGBoost. Moving to next.
# Trained fit 3250/34560 for XGBoost. Moving to next.
# Trained fit 3300/34560 for XGBoost. Moving to next.
# Trained fit 3350/34560 for XGBoost. Moving to next.
# Trained fit 3400/34560 for XGBoost. Moving to next.
# Trained fit 3450/34560 for XGBoost. Moving to next.
# Trained fit 3500/34560 for XGBoost. Moving to next.
# Trained fit 3550/34560 for XGBoost. Moving to next.
# Trained fit 3600/34560 for XGBoost. Moving to next.
# Trained fit 3650/34560 for XGBoost. Moving to next.
# Trained fit 3700/34560 for XGBoost. Moving to next.
# Trained fit 3750/34560 for XGBoost. Moving to next.
# Trained fit 3800/34560 for XGBoost. Moving to next.
# Trained fit 3850/34560 for XGBoost. Moving to next.
# Trained fit 3900/34560 for XGBoost. Moving to next.
# Trained fit 3950/34560 for XGBoost. Moving to next.
# Trained fit 4000/34560 for XGBoost. Moving to next.
# Trained fit 4050/34560 for XGBoost. Moving to next.
# Trained fit 4100/34560 for XGBoost. Moving to next.
# Trained fit 4150/34560 for XGBoost. Moving to next.
# Trained fit 4200/34560 for XGBoost. Moving to next.
# Trained fit 4250/34560 for XGBoost. Moving to next.
# Trained fit 4300/34560 for XGBoost. Moving to next.
# Trained fit 4350/34560 for XGBoost. Moving to next.
# Trained fit 4400/34560 for XGBoost. Moving to next.
# Trained fit 4450/34560 for XGBoost. Moving to next.
# Trained fit 4500/34560 for XGBoost. Moving to next.
# Trained fit 4550/34560 for XGBoost. Moving to next.
# Trained fit 4600/34560 for XGBoost. Moving to next.
# Trained fit 4650/34560 for XGBoost. Moving to next.
# Trained fit 4700/34560 for XGBoost. Moving to next.
# Trained fit 4750/34560 for XGBoost. Moving to next.
# Trained fit 4800/34560 for XGBoost. Moving to next.
# Trained fit 4850/34560 for XGBoost. Moving to next.
# Trained fit 4900/34560 for XGBoost. Moving to next.
# Trained fit 4950/34560 for XGBoost. Moving to next.
# Trained fit 5000/34560 for XGBoost. Moving to next.
# Trained fit 5050/34560 for XGBoost. Moving to next.
# Trained fit 5100/34560 for XGBoost. Moving to next.
# Trained fit 5150/34560 for XGBoost. Moving to next.
# Trained fit 5200/34560 for XGBoost. Moving to next.
# Trained fit 5250/34560 for XGBoost. Moving to next.
# Trained fit 5300/34560 for XGBoost. Moving to next.
# Trained fit 5350/34560 for XGBoost. Moving to next.
# Trained fit 5400/34560 for XGBoost. Moving to next.
# Trained fit 5450/34560 for XGBoost. Moving to next.
# Trained fit 5500/34560 for XGBoost. Moving to next.
# Trained fit 5550/34560 for XGBoost. Moving to next.
# Trained fit 5600/34560 for XGBoost. Moving to next.
# Trained fit 5650/34560 for XGBoost. Moving to next.
# Trained fit 5700/34560 for XGBoost. Moving to next.
# Trained fit 5750/34560 for XGBoost. Moving to next.
# Trained fit 5800/34560 for XGBoost. Moving to next.
# Trained fit 5850/34560 for XGBoost. Moving to next.
# Trained fit 5900/34560 for XGBoost. Moving to next.
# Trained fit 5950/34560 for XGBoost. Moving to next.
# Trained fit 6000/34560 for XGBoost. Moving to next.
# Trained fit 6050/34560 for XGBoost. Moving to next.
# Trained fit 6100/34560 for XGBoost. Moving to next.
# Trained fit 6150/34560 for XGBoost. Moving to next.
# Trained fit 6200/34560 for XGBoost. Moving to next.
# Trained fit 6250/34560 for XGBoost. Moving to next.
# Trained fit 6300/34560 for XGBoost. Moving to next.
# Trained fit 6350/34560 for XGBoost. Moving to next.
# Trained fit 6400/34560 for XGBoost. Moving to next.
# Trained fit 6450/34560 for XGBoost. Moving to next.
# Trained fit 6500/34560 for XGBoost. Moving to next.
# Trained fit 6550/34560 for XGBoost. Moving to next.
# Trained fit 6600/34560 for XGBoost. Moving to next.
# Trained fit 6650/34560 for XGBoost. Moving to next.
# Trained fit 6700/34560 for XGBoost. Moving to next.
# Trained fit 6750/34560 for XGBoost. Moving to next.
# Trained fit 6800/34560 for XGBoost. Moving to next.
# Trained fit 6850/34560 for XGBoost. Moving to next.
# Trained fit 6900/34560 for XGBoost. Moving to next.
# Trained fit 6950/34560 for XGBoost. Moving to next.
# Trained fit 7000/34560 for XGBoost. Moving to next.
# Trained fit 7050/34560 for XGBoost. Moving to next.
# Trained fit 7100/34560 for XGBoost. Moving to next.
# Trained fit 7150/34560 for XGBoost. Moving to next.
# Trained fit 7200/34560 for XGBoost. Moving to next.
# Trained fit 7250/34560 for XGBoost. Moving to next.
# Trained fit 7300/34560 for XGBoost. Moving to next.
# Trained fit 7350/34560 for XGBoost. Moving to next.
# Trained fit 7400/34560 for XGBoost. Moving to next.
# Trained fit 7450/34560 for XGBoost. Moving to next.
# Trained fit 7500/34560 for XGBoost. Moving to next.
# Trained fit 7550/34560 for XGBoost. Moving to next.
# Trained fit 7600/34560 for XGBoost. Moving to next.
# Trained fit 7650/34560 for XGBoost. Moving to next.
# Trained fit 7700/34560 for XGBoost. Moving to next.
# Trained fit 7750/34560 for XGBoost. Moving to next.
# Trained fit 7800/34560 for XGBoost. Moving to next.
# Trained fit 7850/34560 for XGBoost. Moving to next.
# Trained fit 7900/34560 for XGBoost. Moving to next.
# Trained fit 7950/34560 for XGBoost. Moving to next.
# Trained fit 8000/34560 for XGBoost. Moving to next.
# Trained fit 8050/34560 for XGBoost. Moving to next.
# Trained fit 8100/34560 for XGBoost. Moving to next.
# Trained fit 8150/34560 for XGBoost. Moving to next.
# Trained fit 8200/34560 for XGBoost. Moving to next.
# Trained fit 8250/34560 for XGBoost. Moving to next.
# Trained fit 8300/34560 for XGBoost. Moving to next.
# Trained fit 8350/34560 for XGBoost. Moving to next.
# Trained fit 8400/34560 for XGBoost. Moving to next.
# Trained fit 8450/34560 for XGBoost. Moving to next.
# Trained fit 8500/34560 for XGBoost. Moving to next.
# Trained fit 8550/34560 for XGBoost. Moving to next.
# Trained fit 8600/34560 for XGBoost. Moving to next.
# Trained fit 8650/34560 for XGBoost. Moving to next.
# Trained fit 8700/34560 for XGBoost. Moving to next.
# Trained fit 8750/34560 for XGBoost. Moving to next.
# Trained fit 8800/34560 for XGBoost. Moving to next.
# Trained fit 8850/34560 for XGBoost. Moving to next.
# Trained fit 8900/34560 for XGBoost. Moving to next.
# Trained fit 8950/34560 for XGBoost. Moving to next.
# Trained fit 9000/34560 for XGBoost. Moving to next.
# Trained fit 9050/34560 for XGBoost. Moving to next.
# Trained fit 9100/34560 for XGBoost. Moving to next.
# Trained fit 9150/34560 for XGBoost. Moving to next.
# Trained fit 9200/34560 for XGBoost. Moving to next.
# Trained fit 9250/34560 for XGBoost. Moving to next.
# Trained fit 9300/34560 for XGBoost. Moving to next.
# Trained fit 9350/34560 for XGBoost. Moving to next.
# Trained fit 9400/34560 for XGBoost. Moving to next.
# Trained fit 9450/34560 for XGBoost. Moving to next.
# Trained fit 9500/34560 for XGBoost. Moving to next.
# Trained fit 9550/34560 for XGBoost. Moving to next.
# Trained fit 9600/34560 for XGBoost. Moving to next.
# Trained fit 9650/34560 for XGBoost. Moving to next.
# Trained fit 9700/34560 for XGBoost. Moving to next.
# Trained fit 9750/34560 for XGBoost. Moving to next.
# Trained fit 9800/34560 for XGBoost. Moving to next.
# Trained fit 9850/34560 for XGBoost. Moving to next.
# Trained fit 9900/34560 for XGBoost. Moving to next.
# Trained fit 9950/34560 for XGBoost. Moving to next.
# Trained fit 10000/34560 for XGBoost. Moving to next.
# Trained fit 10050/34560 for XGBoost. Moving to next.
# Trained fit 10100/34560 for XGBoost. Moving to next.
# Trained fit 10150/34560 for XGBoost. Moving to next.
# Trained fit 10200/34560 for XGBoost. Moving to next.
# Trained fit 10250/34560 for XGBoost. Moving to next.
# Trained fit 10300/34560 for XGBoost. Moving to next.
# Trained fit 10350/34560 for XGBoost. Moving to next.
# Trained fit 10400/34560 for XGBoost. Moving to next.
# Trained fit 10450/34560 for XGBoost. Moving to next.
# Trained fit 10500/34560 for XGBoost. Moving to next.
# Trained fit 10550/34560 for XGBoost. Moving to next.
# Trained fit 10600/34560 for XGBoost. Moving to next.
# Trained fit 10650/34560 for XGBoost. Moving to next.
# Trained fit 10700/34560 for XGBoost. Moving to next.
# Trained fit 10750/34560 for XGBoost. Moving to next.
# Trained fit 10800/34560 for XGBoost. Moving to next.
# Trained fit 10850/34560 for XGBoost. Moving to next.
# Trained fit 10900/34560 for XGBoost. Moving to next.
# Trained fit 10950/34560 for XGBoost. Moving to next.
# Trained fit 11000/34560 for XGBoost. Moving to next.
# Trained fit 11050/34560 for XGBoost. Moving to next.
# Trained fit 11100/34560 for XGBoost. Moving to next.
# Trained fit 11150/34560 for XGBoost. Moving to next.
# Trained fit 11200/34560 for XGBoost. Moving to next.
# Trained fit 11250/34560 for XGBoost. Moving to next.
# Trained fit 11300/34560 for XGBoost. Moving to next.
# Trained fit 11350/34560 for XGBoost. Moving to next.
# Trained fit 11400/34560 for XGBoost. Moving to next.
# Trained fit 11450/34560 for XGBoost. Moving to next.
# Trained fit 11500/34560 for XGBoost. Moving to next.
# Trained fit 11550/34560 for XGBoost. Moving to next.
# Trained fit 11600/34560 for XGBoost. Moving to next.
# Trained fit 11650/34560 for XGBoost. Moving to next.
# Trained fit 11700/34560 for XGBoost. Moving to next.
# Trained fit 11750/34560 for XGBoost. Moving to next.
# Trained fit 11800/34560 for XGBoost. Moving to next.
# Trained fit 11850/34560 for XGBoost. Moving to next.
# Trained fit 11900/34560 for XGBoost. Moving to next.
# Trained fit 11950/34560 for XGBoost. Moving to next.
# Trained fit 12000/34560 for XGBoost. Moving to next.
# Trained fit 12050/34560 for XGBoost. Moving to next.
# Trained fit 12100/34560 for XGBoost. Moving to next.
# Trained fit 12150/34560 for XGBoost. Moving to next.
# Trained fit 12200/34560 for XGBoost. Moving to next.
# Trained fit 12250/34560 for XGBoost. Moving to next.
# Trained fit 12300/34560 for XGBoost. Moving to next.
# Trained fit 12350/34560 for XGBoost. Moving to next.
# Trained fit 12400/34560 for XGBoost. Moving to next.
# Trained fit 12450/34560 for XGBoost. Moving to next.
# Trained fit 12500/34560 for XGBoost. Moving to next.
# Trained fit 12550/34560 for XGBoost. Moving to next.
# Trained fit 12600/34560 for XGBoost. Moving to next.
# Trained fit 12650/34560 for XGBoost. Moving to next.
# Trained fit 12700/34560 for XGBoost. Moving to next.
# Trained fit 12750/34560 for XGBoost. Moving to next.
# Trained fit 12800/34560 for XGBoost. Moving to next.
# Trained fit 12850/34560 for XGBoost. Moving to next.
# Trained fit 12900/34560 for XGBoost. Moving to next.
# Trained fit 12950/34560 for XGBoost. Moving to next.
# Trained fit 13000/34560 for XGBoost. Moving to next.
# Trained fit 13050/34560 for XGBoost. Moving to next.
# Trained fit 13100/34560 for XGBoost. Moving to next.
# Trained fit 13150/34560 for XGBoost. Moving to next.
# Trained fit 13200/34560 for XGBoost. Moving to next.
# Trained fit 13250/34560 for XGBoost. Moving to next.
# Trained fit 13300/34560 for XGBoost. Moving to next.
# Trained fit 13350/34560 for XGBoost. Moving to next.
# Trained fit 13400/34560 for XGBoost. Moving to next.
# Trained fit 13450/34560 for XGBoost. Moving to next.
# Trained fit 13500/34560 for XGBoost. Moving to next.
# Trained fit 13550/34560 for XGBoost. Moving to next.
# Trained fit 13600/34560 for XGBoost. Moving to next.
# Trained fit 13650/34560 for XGBoost. Moving to next.
# Trained fit 13700/34560 for XGBoost. Moving to next.
# Trained fit 13750/34560 for XGBoost. Moving to next.
# Trained fit 13800/34560 for XGBoost. Moving to next.
# Trained fit 13850/34560 for XGBoost. Moving to next.
# Trained fit 13900/34560 for XGBoost. Moving to next.
# Trained fit 13950/34560 for XGBoost. Moving to next.
# Trained fit 14000/34560 for XGBoost. Moving to next.
# Trained fit 14050/34560 for XGBoost. Moving to next.
# Trained fit 14100/34560 for XGBoost. Moving to next.
# Trained fit 14150/34560 for XGBoost. Moving to next.
# Trained fit 14200/34560 for XGBoost. Moving to next.
# Trained fit 14250/34560 for XGBoost. Moving to next.
# Trained fit 14300/34560 for XGBoost. Moving to next.
# Trained fit 14350/34560 for XGBoost. Moving to next.
# Trained fit 14400/34560 for XGBoost. Moving to next.
# Trained fit 14450/34560 for XGBoost. Moving to next.
# Trained fit 14500/34560 for XGBoost. Moving to next.
# Trained fit 14550/34560 for XGBoost. Moving to next.
# Trained fit 14600/34560 for XGBoost. Moving to next.
# Trained fit 14650/34560 for XGBoost. Moving to next.
# Trained fit 14700/34560 for XGBoost. Moving to next.
# Trained fit 14750/34560 for XGBoost. Moving to next.
# Trained fit 14800/34560 for XGBoost. Moving to next.
# Trained fit 14850/34560 for XGBoost. Moving to next.
# Trained fit 14900/34560 for XGBoost. Moving to next.
# Trained fit 14950/34560 for XGBoost. Moving to next.
# Trained fit 15000/34560 for XGBoost. Moving to next.
# Trained fit 15050/34560 for XGBoost. Moving to next.
# Trained fit 15100/34560 for XGBoost. Moving to next.
# Trained fit 15150/34560 for XGBoost. Moving to next.
# Trained fit 15200/34560 for XGBoost. Moving to next.
# Trained fit 15250/34560 for XGBoost. Moving to next.
# Trained fit 15300/34560 for XGBoost. Moving to next.
# Trained fit 15350/34560 for XGBoost. Moving to next.
# Trained fit 15400/34560 for XGBoost. Moving to next.
# Trained fit 15450/34560 for XGBoost. Moving to next.
# Trained fit 15500/34560 for XGBoost. Moving to next.
# Trained fit 15550/34560 for XGBoost. Moving to next.
# Trained fit 15600/34560 for XGBoost. Moving to next.
# Trained fit 15650/34560 for XGBoost. Moving to next.
# Trained fit 15700/34560 for XGBoost. Moving to next.
# Trained fit 15750/34560 for XGBoost. Moving to next.
# Trained fit 15800/34560 for XGBoost. Moving to next.
# Trained fit 15850/34560 for XGBoost. Moving to next.
# Trained fit 15900/34560 for XGBoost. Moving to next.
# Trained fit 15950/34560 for XGBoost. Moving to next.
# Trained fit 16000/34560 for XGBoost. Moving to next.
# Trained fit 16050/34560 for XGBoost. Moving to next.
# Trained fit 16100/34560 for XGBoost. Moving to next.
# Trained fit 16150/34560 for XGBoost. Moving to next.
# Trained fit 16200/34560 for XGBoost. Moving to next.
# Trained fit 16250/34560 for XGBoost. Moving to next.
# Trained fit 16300/34560 for XGBoost. Moving to next.
# Trained fit 16350/34560 for XGBoost. Moving to next.
# Trained fit 16400/34560 for XGBoost. Moving to next.
# Trained fit 16450/34560 for XGBoost. Moving to next.
# Trained fit 16500/34560 for XGBoost. Moving to next.
# Trained fit 16550/34560 for XGBoost. Moving to next.
# Trained fit 16600/34560 for XGBoost. Moving to next.
# Trained fit 16650/34560 for XGBoost. Moving to next.
# Trained fit 16700/34560 for XGBoost. Moving to next.
# Trained fit 16750/34560 for XGBoost. Moving to next.
# Trained fit 16800/34560 for XGBoost. Moving to next.
# Trained fit 16850/34560 for XGBoost. Moving to next.
# Trained fit 16900/34560 for XGBoost. Moving to next.
# Trained fit 16950/34560 for XGBoost. Moving to next.
# Trained fit 17000/34560 for XGBoost. Moving to next.
# Trained fit 17050/34560 for XGBoost. Moving to next.
# Trained fit 17100/34560 for XGBoost. Moving to next.
# Trained fit 17150/34560 for XGBoost. Moving to next.
# Trained fit 17200/34560 for XGBoost. Moving to next.
# Trained fit 17250/34560 for XGBoost. Moving to next.
# Trained fit 17300/34560 for XGBoost. Moving to next.
# Trained fit 17350/34560 for XGBoost. Moving to next.
# Trained fit 17400/34560 for XGBoost. Moving to next.
# Trained fit 17450/34560 for XGBoost. Moving to next.
# Trained fit 17500/34560 for XGBoost. Moving to next.
# Trained fit 17550/34560 for XGBoost. Moving to next.
# Trained fit 17600/34560 for XGBoost. Moving to next.
# Trained fit 17650/34560 for XGBoost. Moving to next.
# Trained fit 17700/34560 for XGBoost. Moving to next.
# Trained fit 17750/34560 for XGBoost. Moving to next.
# Trained fit 17800/34560 for XGBoost. Moving to next.
# Trained fit 17850/34560 for XGBoost. Moving to next.
# Trained fit 17900/34560 for XGBoost. Moving to next.
# Trained fit 17950/34560 for XGBoost. Moving to next.
# Trained fit 18000/34560 for XGBoost. Moving to next.
# Trained fit 18050/34560 for XGBoost. Moving to next.
# Trained fit 18100/34560 for XGBoost. Moving to next.
# Trained fit 18150/34560 for XGBoost. Moving to next.
# Trained fit 18200/34560 for XGBoost. Moving to next.
# Trained fit 18250/34560 for XGBoost. Moving to next.
# Trained fit 18300/34560 for XGBoost. Moving to next.
# Trained fit 18350/34560 for XGBoost. Moving to next.
# Trained fit 18400/34560 for XGBoost. Moving to next.
# Trained fit 18450/34560 for XGBoost. Moving to next.
# Trained fit 18500/34560 for XGBoost. Moving to next.
# Trained fit 18550/34560 for XGBoost. Moving to next.
# Trained fit 18600/34560 for XGBoost. Moving to next.
# Trained fit 18650/34560 for XGBoost. Moving to next.
# Trained fit 18700/34560 for XGBoost. Moving to next.
# Trained fit 18750/34560 for XGBoost. Moving to next.
# Trained fit 18800/34560 for XGBoost. Moving to next.
# Trained fit 18850/34560 for XGBoost. Moving to next.
# Trained fit 18900/34560 for XGBoost. Moving to next.
# Trained fit 18950/34560 for XGBoost. Moving to next.
# Trained fit 19000/34560 for XGBoost. Moving to next.
# Trained fit 19050/34560 for XGBoost. Moving to next.
# Trained fit 19100/34560 for XGBoost. Moving to next.
# Trained fit 19150/34560 for XGBoost. Moving to next.
# Trained fit 19200/34560 for XGBoost. Moving to next.
# Trained fit 19250/34560 for XGBoost. Moving to next.
# Trained fit 19300/34560 for XGBoost. Moving to next.
# Trained fit 19350/34560 for XGBoost. Moving to next.
# Trained fit 19400/34560 for XGBoost. Moving to next.
# Trained fit 19450/34560 for XGBoost. Moving to next.
# Trained fit 19500/34560 for XGBoost. Moving to next.
# Trained fit 19550/34560 for XGBoost. Moving to next.
# Trained fit 19600/34560 for XGBoost. Moving to next.
# Trained fit 19650/34560 for XGBoost. Moving to next.
# Trained fit 19700/34560 for XGBoost. Moving to next.
# Trained fit 19750/34560 for XGBoost. Moving to next.
# Trained fit 19800/34560 for XGBoost. Moving to next.
# Trained fit 19850/34560 for XGBoost. Moving to next.
# Trained fit 19900/34560 for XGBoost. Moving to next.
# Trained fit 19950/34560 for XGBoost. Moving to next.
# Trained fit 20000/34560 for XGBoost. Moving to next.
# Trained fit 20050/34560 for XGBoost. Moving to next.
# Trained fit 20100/34560 for XGBoost. Moving to next.
# Trained fit 20150/34560 for XGBoost. Moving to next.
# Trained fit 20200/34560 for XGBoost. Moving to next.
# Trained fit 20250/34560 for XGBoost. Moving to next.
# Trained fit 20300/34560 for XGBoost. Moving to next.
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.708e-01, tolerance: 1.620e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.760e-01, tolerance: 1.620e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.760e-01, tolerance: 1.620e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.268e-01, tolerance: 1.620e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.259e-01, tolerance: 1.620e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.612e-01, tolerance: 1.620e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.612e-01, tolerance: 1.620e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.089e-01, tolerance: 1.620e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.027e-01, tolerance: 1.620e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.280e+00, tolerance: 1.620e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.280e+00, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.340e+00, tolerance: 1.620e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.340e+00, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.215e+00, tolerance: 1.620e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.215e+00, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.994e-02, tolerance: 1.620e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.994e-02, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.180e-03, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# Trained fit 50/612 for ElasticNet. Moving to next.
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.543e-02, tolerance: 1.620e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.543e-02, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/michelle/Library/Python/3.11/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.340e-03, tolerance: 1.620e-03
#   model = cd_fast.enet_coordinate_descent(
# Trained fit 100/612 for ElasticNet. Moving to next.
# Trained fit 150/612 for ElasticNet. Moving to next.
# Trained fit 200/612 for ElasticNet. Moving to next.
# Trained fit 250/612 for ElasticNet. Moving to next.
# Trained fit 300/612 for ElasticNet. Moving to next.
# Trained fit 350/612 for ElasticNet. Moving to next.
# Trained fit 400/612 for ElasticNet. Moving to next.
# Trained fit 450/612 for ElasticNet. Moving to next.
# Trained fit 500/612 for ElasticNet. Moving to next.
# Trained fit 550/612 for ElasticNet. Moving to next.
# Trained fit 600/612 for ElasticNet. Moving to next.
# Finished tuning for ElasticNet.
# Best Parameters for ElasticNet: {'alpha': 0.01, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 2000, 'selection': 'cyclic', 'tol': 0.0001}
# Best Validation MSE for ElasticNet: 0.8537
#
# Final Results for All Models:
# NeuralNetwork - Best Params: {'activation': 'relu', 'alpha': 1, 'early_stopping': True, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1, 'max_iter': 2500, 'momentum': 0.9, 'solver': 'adam'}, Best Validation MSE: 0.3824
# XGBoost - Best Params: {'alpha': 0.1, 'colsample_bytree': 0.15, 'gamma': 0, 'lambda': 0, 'learning_rate': 0.3, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0}, Best Validation MSE: 0.5248
# SGD - Best Params: {'alpha': 1, 'fit_intercept': True, 'learning_rate': 'invscaling', 'max_iter': 1500, 'penalty': 'l2', 'power_t': 0.8, 'tol': 0.001}, Best Validation MSE: 0.7056
# RandomForest - Best Params: {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}, Best Validation MSE: 0.5887
# ElasticNet - Best Params: {'alpha': 0.01, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 2000, 'selection': 'cyclic', 'tol': 0.0001}, Best Validation MSE: 0.8537

# %%
# Sort models by validation MSE
sorted_results = sorted(model_results.items(), key=lambda x: x[1]['best_val_mse'])

# Select the best model (lowest MSE)
best_model_name, best_model_result = sorted_results[0]

# Display sorted results
print("Sorted Model Tuning Results:")
for model_name, result in sorted_results:
    print(f"{model_name}:")
    print(f"  Best Parameters: {result['best_params']}")
    print(f"  Validation MSE: {result['best_val_mse']:.4f}")

# Display the best model
print("\nBest Model Selected:")
print(f"{best_model_name}:")
print(f"  Best Parameters: {best_model_result['best_params']}")
print(f"  Validation MSE: {best_model_result['best_val_mse']:.4f}")
# Out:
# Sorted Model Tuning Results:
# NeuralNetwork:
#   Best Parameters: {'activation': 'relu', 'alpha': 1, 'early_stopping': True, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1, 'max_iter': 2500, 'momentum': 0.9, 'solver': 'adam'}
#   Validation MSE: 0.3824
# XGBoost:
#   Best Parameters: {'alpha': 0.1, 'colsample_bytree': 0.15, 'gamma': 0, 'lambda': 0, 'learning_rate': 0.3, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0}
#   Validation MSE: 0.5248
# RandomForest:
#   Best Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#   Validation MSE: 0.5887
# SGD:
#   Best Parameters: {'alpha': 1, 'fit_intercept': True, 'learning_rate': 'invscaling', 'max_iter': 1500, 'penalty': 'l2', 'power_t': 0.8, 'tol': 0.001}
#   Validation MSE: 0.7056
# ElasticNet:
#   Best Parameters: {'alpha': 0.01, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 2000, 'selection': 'cyclic', 'tol': 0.0001}
#   Validation MSE: 0.8537
#
# Best Model Selected:
# NeuralNetwork:
#   Best Parameters: {'activation': 'relu', 'alpha': 1, 'early_stopping': True, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'learning_rate_init': 0.1, 'max_iter': 2500, 'momentum': 0.9, 'solver': 'adam'}
#   Validation MSE: 0.3824

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate scatterplots for the best model of each type
for model_name, model in models.items():
    if model_name not in model_results:
        continue  # Skip if the model isn't in the results

    best_params = model_results[model_name]["best_params"]  # Get the best hyperparameters

    # Re-initialize the model with the best parameters
    best_model = model.set_params(**best_params)

    # Fit the model on the training data (if needed)
    best_model.fit(X_train_scaled, y_Outflow_train_scaled)

    # Generate predictions on validation data
    y_pred_scaled = best_model.predict(X_val_scaled)

    # **Inverse transform predictions and actual values**
    y_pred = outyscaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Scatterplot of predicted vs actual
    plt.figure(figsize=(6, 6))
    plt.scatter(y_Outflow_val, y_pred, alpha=0.5)

    # Plot y = x line for reference
    min_val, max_val = min(y_Outflow_val_scaled.min(), y_pred.min()), max(y_Outflow_val_scaled.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], linestyle="--", color="red", label="Ideal Fit")

    # Labels and title
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title(f"Predicted vs. Actual for {model_name}")
    plt.legend()

    # Show the plot
    plt.show()

# %%
# Tuning III: greedy grid for best, XGBoost (because of visual fit)!

from sklearn.model_selection import ParameterGrid

# Define greedy tuning grid
greedy_param_grid = {
        'learning_rate': [0.01, 0.1, 0.3, 0.4, 0.5],
        'n_estimators': [10, 15, 25, 35, 50],
        'max_depth': [1, 2, 5, 7, 10, 15, 20, 25, 50, 100, 150],
        'subsample': [0.95, 1.0],
        'colsample_bytree': [0.025, 0.075, 0.1, 0.2, 0.3],
        'gamma': [0, 0.1, 0.3],
        'alpha': [0, 0.2],  
        'lambda': [0, 0.1, 0.2, 0.3, 0.5]  
}


# Create parameter combinations
param_combinations = list(ParameterGrid(greedy_param_grid))

print(f"Total parameter combinations to try: {len(param_combinations)}")
# Out:
# Total parameter combinations to try: 82500

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_squared_error

# Initialize best model tracking
best_rmse = float('inf')
best_model = None
best_params = None
i = 0

# Iterate over all parameter combinations
for params in ParameterGrid(greedy_param_grid):
    #print(f"Testing parameters: {params}")

    # Initialize and train the model
    model = xgboost.XGBRegressor(**params, random_state=42)
    model.fit(X_train_scaled, y_Outflow_train_scaled)

    # Predict on validation set
    y_pred_scaled = model.predict(X_val_scaled)

    # **Inverse transform predictions and actual values**
    y_pred = outyscaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Compute validation MSE
    val_rmse = np.sqrt(mean_squared_error(y_Outflow_val, y_pred))
    #print(f"Validation MSE: {val_mse:.4f}")

    i += 1
    if i % 50 == 0:
        print(f"Trained fit {i}/{len(ParameterGrid(greedy_param_grid))}. Moving to next.")
    
    # Track best model
    if val_rmse < best_rmse:
        best_rmse = val_rmse
        best_model = model
        best_params = params

print("\nBest Model Found:")
print(f"Best Parameters: {best_params}")
print(f"Best Validation RMSE: {best_rmse:.4f}")
# Out:
# Trained fit 50/82500. Moving to next.
# Trained fit 100/82500. Moving to next.
# Trained fit 150/82500. Moving to next.
# Trained fit 200/82500. Moving to next.
# Trained fit 250/82500. Moving to next.
# Trained fit 300/82500. Moving to next.
# Trained fit 350/82500. Moving to next.
# Trained fit 400/82500. Moving to next.
# Trained fit 450/82500. Moving to next.
# Trained fit 500/82500. Moving to next.
# Trained fit 550/82500. Moving to next.
# Trained fit 600/82500. Moving to next.
# Trained fit 650/82500. Moving to next.
# Trained fit 700/82500. Moving to next.
# Trained fit 750/82500. Moving to next.
# Trained fit 800/82500. Moving to next.
# Trained fit 850/82500. Moving to next.
# Trained fit 900/82500. Moving to next.
# Trained fit 950/82500. Moving to next.
# Trained fit 1000/82500. Moving to next.
# Trained fit 1050/82500. Moving to next.
# Trained fit 1100/82500. Moving to next.
# Trained fit 1150/82500. Moving to next.
# Trained fit 1200/82500. Moving to next.
# Trained fit 1250/82500. Moving to next.
# Trained fit 1300/82500. Moving to next.
# Trained fit 1350/82500. Moving to next.
# Trained fit 1400/82500. Moving to next.
# Trained fit 1450/82500. Moving to next.
# Trained fit 1500/82500. Moving to next.
# Trained fit 1550/82500. Moving to next.
# Trained fit 1600/82500. Moving to next.
# Trained fit 1650/82500. Moving to next.
# Trained fit 1700/82500. Moving to next.
# Trained fit 1750/82500. Moving to next.
# Trained fit 1800/82500. Moving to next.
# Trained fit 1850/82500. Moving to next.
# Trained fit 1900/82500. Moving to next.
# Trained fit 1950/82500. Moving to next.
# Trained fit 2000/82500. Moving to next.
# Trained fit 2050/82500. Moving to next.
# Trained fit 2100/82500. Moving to next.
# Trained fit 2150/82500. Moving to next.
# Trained fit 2200/82500. Moving to next.
# Trained fit 2250/82500. Moving to next.
# Trained fit 2300/82500. Moving to next.
# Trained fit 2350/82500. Moving to next.
# Trained fit 2400/82500. Moving to next.
# Trained fit 2450/82500. Moving to next.
# Trained fit 2500/82500. Moving to next.
# Trained fit 2550/82500. Moving to next.
# Trained fit 2600/82500. Moving to next.
# Trained fit 2650/82500. Moving to next.
# Trained fit 2700/82500. Moving to next.
# Trained fit 2750/82500. Moving to next.
# Trained fit 2800/82500. Moving to next.
# Trained fit 2850/82500. Moving to next.
# Trained fit 2900/82500. Moving to next.
# Trained fit 2950/82500. Moving to next.
# Trained fit 3000/82500. Moving to next.
# Trained fit 3050/82500. Moving to next.
# Trained fit 3100/82500. Moving to next.
# Trained fit 3150/82500. Moving to next.
# Trained fit 3200/82500. Moving to next.
# Trained fit 3250/82500. Moving to next.
# Trained fit 3300/82500. Moving to next.
# Trained fit 3350/82500. Moving to next.
# Trained fit 3400/82500. Moving to next.
# Trained fit 3450/82500. Moving to next.
# Trained fit 3500/82500. Moving to next.
# Trained fit 3550/82500. Moving to next.
# Trained fit 3600/82500. Moving to next.
# Trained fit 3650/82500. Moving to next.
# Trained fit 3700/82500. Moving to next.
# Trained fit 3750/82500. Moving to next.
# Trained fit 3800/82500. Moving to next.
# Trained fit 3850/82500. Moving to next.
# Trained fit 3900/82500. Moving to next.
# Trained fit 3950/82500. Moving to next.
# Trained fit 4000/82500. Moving to next.
# Trained fit 4050/82500. Moving to next.
# Trained fit 4100/82500. Moving to next.
# Trained fit 4150/82500. Moving to next.
# Trained fit 4200/82500. Moving to next.
# Trained fit 4250/82500. Moving to next.
# Trained fit 4300/82500. Moving to next.
# Trained fit 4350/82500. Moving to next.
# Trained fit 4400/82500. Moving to next.
# Trained fit 4450/82500. Moving to next.
# Trained fit 4500/82500. Moving to next.
# Trained fit 4550/82500. Moving to next.
# Trained fit 4600/82500. Moving to next.
# Trained fit 4650/82500. Moving to next.
# Trained fit 4700/82500. Moving to next.
# Trained fit 4750/82500. Moving to next.
# Trained fit 4800/82500. Moving to next.
# Trained fit 4850/82500. Moving to next.
# Trained fit 4900/82500. Moving to next.
# Trained fit 4950/82500. Moving to next.
# Trained fit 5000/82500. Moving to next.
# Trained fit 5050/82500. Moving to next.
# Trained fit 5100/82500. Moving to next.
# Trained fit 5150/82500. Moving to next.
# Trained fit 5200/82500. Moving to next.
# Trained fit 5250/82500. Moving to next.
# Trained fit 5300/82500. Moving to next.
# Trained fit 5350/82500. Moving to next.
# Trained fit 5400/82500. Moving to next.
# Trained fit 5450/82500. Moving to next.
# Trained fit 5500/82500. Moving to next.
# Trained fit 5550/82500. Moving to next.
# Trained fit 5600/82500. Moving to next.
# Trained fit 5650/82500. Moving to next.
# Trained fit 5700/82500. Moving to next.
# Trained fit 5750/82500. Moving to next.
# Trained fit 5800/82500. Moving to next.
# Trained fit 5850/82500. Moving to next.
# Trained fit 5900/82500. Moving to next.
# Trained fit 5950/82500. Moving to next.
# Trained fit 6000/82500. Moving to next.
# Trained fit 6050/82500. Moving to next.
# Trained fit 6100/82500. Moving to next.
# Trained fit 6150/82500. Moving to next.
# Trained fit 6200/82500. Moving to next.
# Trained fit 6250/82500. Moving to next.
# Trained fit 6300/82500. Moving to next.
# Trained fit 6350/82500. Moving to next.
# Trained fit 6400/82500. Moving to next.
# Trained fit 6450/82500. Moving to next.
# Trained fit 6500/82500. Moving to next.
# Trained fit 6550/82500. Moving to next.
# Trained fit 6600/82500. Moving to next.
# Trained fit 6650/82500. Moving to next.
# Trained fit 6700/82500. Moving to next.
# Trained fit 6750/82500. Moving to next.
# Trained fit 6800/82500. Moving to next.
# Trained fit 6850/82500. Moving to next.
# Trained fit 6900/82500. Moving to next.
# Trained fit 6950/82500. Moving to next.
# Trained fit 7000/82500. Moving to next.
# Trained fit 7050/82500. Moving to next.
# Trained fit 7100/82500. Moving to next.
# Trained fit 7150/82500. Moving to next.
# Trained fit 7200/82500. Moving to next.
# Trained fit 7250/82500. Moving to next.
# Trained fit 7300/82500. Moving to next.
# Trained fit 7350/82500. Moving to next.
# Trained fit 7400/82500. Moving to next.
# Trained fit 7450/82500. Moving to next.
# Trained fit 7500/82500. Moving to next.
# Trained fit 7550/82500. Moving to next.
# Trained fit 7600/82500. Moving to next.
# Trained fit 7650/82500. Moving to next.
# Trained fit 7700/82500. Moving to next.
# Trained fit 7750/82500. Moving to next.
# Trained fit 7800/82500. Moving to next.
# Trained fit 7850/82500. Moving to next.
# Trained fit 7900/82500. Moving to next.
# Trained fit 7950/82500. Moving to next.
# Trained fit 8000/82500. Moving to next.
# Trained fit 8050/82500. Moving to next.
# Trained fit 8100/82500. Moving to next.
# Trained fit 8150/82500. Moving to next.
# Trained fit 8200/82500. Moving to next.
# Trained fit 8250/82500. Moving to next.
# Trained fit 8300/82500. Moving to next.
# Trained fit 8350/82500. Moving to next.
# Trained fit 8400/82500. Moving to next.
# Trained fit 8450/82500. Moving to next.
# Trained fit 8500/82500. Moving to next.
# Trained fit 8550/82500. Moving to next.
# Trained fit 8600/82500. Moving to next.
# Trained fit 8650/82500. Moving to next.
# Trained fit 8700/82500. Moving to next.
# Trained fit 8750/82500. Moving to next.
# Trained fit 8800/82500. Moving to next.
# Trained fit 8850/82500. Moving to next.
# Trained fit 8900/82500. Moving to next.
# Trained fit 8950/82500. Moving to next.
# Trained fit 9000/82500. Moving to next.
# Trained fit 9050/82500. Moving to next.
# Trained fit 9100/82500. Moving to next.
# Trained fit 9150/82500. Moving to next.
# Trained fit 9200/82500. Moving to next.
# Trained fit 9250/82500. Moving to next.
# Trained fit 9300/82500. Moving to next.
# Trained fit 9350/82500. Moving to next.
# Trained fit 9400/82500. Moving to next.
# Trained fit 9450/82500. Moving to next.
# Trained fit 9500/82500. Moving to next.
# Trained fit 9550/82500. Moving to next.
# Trained fit 9600/82500. Moving to next.
# Trained fit 9650/82500. Moving to next.
# Trained fit 9700/82500. Moving to next.
# Trained fit 9750/82500. Moving to next.
# Trained fit 9800/82500. Moving to next.
# Trained fit 9850/82500. Moving to next.
# Trained fit 9900/82500. Moving to next.
# Trained fit 9950/82500. Moving to next.
# Trained fit 10000/82500. Moving to next.
# Trained fit 10050/82500. Moving to next.
# Trained fit 10100/82500. Moving to next.
# Trained fit 10150/82500. Moving to next.
# Trained fit 10200/82500. Moving to next.
# Trained fit 10250/82500. Moving to next.
# Trained fit 10300/82500. Moving to next.
# Trained fit 10350/82500. Moving to next.
# Trained fit 10400/82500. Moving to next.
# Trained fit 10450/82500. Moving to next.
# Trained fit 10500/82500. Moving to next.
# Trained fit 10550/82500. Moving to next.
# Trained fit 10600/82500. Moving to next.
# Trained fit 10650/82500. Moving to next.
# Trained fit 10700/82500. Moving to next.
# Trained fit 10750/82500. Moving to next.
# Trained fit 10800/82500. Moving to next.
# Trained fit 10850/82500. Moving to next.
# Trained fit 10900/82500. Moving to next.
# Trained fit 10950/82500. Moving to next.
# Trained fit 11000/82500. Moving to next.
# Trained fit 11050/82500. Moving to next.
# Trained fit 11100/82500. Moving to next.
# Trained fit 11150/82500. Moving to next.
# Trained fit 11200/82500. Moving to next.
# Trained fit 11250/82500. Moving to next.
# Trained fit 11300/82500. Moving to next.
# Trained fit 11350/82500. Moving to next.
# Trained fit 11400/82500. Moving to next.
# Trained fit 11450/82500. Moving to next.
# Trained fit 11500/82500. Moving to next.
# Trained fit 11550/82500. Moving to next.
# Trained fit 11600/82500. Moving to next.
# Trained fit 11650/82500. Moving to next.
# Trained fit 11700/82500. Moving to next.
# Trained fit 11750/82500. Moving to next.
# Trained fit 11800/82500. Moving to next.
# Trained fit 11850/82500. Moving to next.
# Trained fit 11900/82500. Moving to next.
# Trained fit 11950/82500. Moving to next.
# Trained fit 12000/82500. Moving to next.
# Trained fit 12050/82500. Moving to next.
# Trained fit 12100/82500. Moving to next.
# Trained fit 12150/82500. Moving to next.
# Trained fit 12200/82500. Moving to next.
# Trained fit 12250/82500. Moving to next.
# Trained fit 12300/82500. Moving to next.
# Trained fit 12350/82500. Moving to next.
# Trained fit 12400/82500. Moving to next.
# Trained fit 12450/82500. Moving to next.
# Trained fit 12500/82500. Moving to next.
# Trained fit 12550/82500. Moving to next.
# Trained fit 12600/82500. Moving to next.
# Trained fit 12650/82500. Moving to next.
# Trained fit 12700/82500. Moving to next.
# Trained fit 12750/82500. Moving to next.
# Trained fit 12800/82500. Moving to next.
# Trained fit 12850/82500. Moving to next.
# Trained fit 12900/82500. Moving to next.
# Trained fit 12950/82500. Moving to next.
# Trained fit 13000/82500. Moving to next.
# Trained fit 13050/82500. Moving to next.
# Trained fit 13100/82500. Moving to next.
# Trained fit 13150/82500. Moving to next.
# Trained fit 13200/82500. Moving to next.
# Trained fit 13250/82500. Moving to next.
# Trained fit 13300/82500. Moving to next.
# Trained fit 13350/82500. Moving to next.
# Trained fit 13400/82500. Moving to next.
# Trained fit 13450/82500. Moving to next.
# Trained fit 13500/82500. Moving to next.
# Trained fit 13550/82500. Moving to next.
# Trained fit 13600/82500. Moving to next.
# Trained fit 13650/82500. Moving to next.
# Trained fit 13700/82500. Moving to next.
# Trained fit 13750/82500. Moving to next.
# Trained fit 13800/82500. Moving to next.
# Trained fit 13850/82500. Moving to next.
# Trained fit 13900/82500. Moving to next.
# Trained fit 13950/82500. Moving to next.
# Trained fit 14000/82500. Moving to next.
# Trained fit 14050/82500. Moving to next.
# Trained fit 14100/82500. Moving to next.
# Trained fit 14150/82500. Moving to next.
# Trained fit 14200/82500. Moving to next.
# Trained fit 14250/82500. Moving to next.
# Trained fit 14300/82500. Moving to next.
# Trained fit 14350/82500. Moving to next.
# Trained fit 14400/82500. Moving to next.
# Trained fit 14450/82500. Moving to next.
# Trained fit 14500/82500. Moving to next.
# Trained fit 14550/82500. Moving to next.
# Trained fit 14600/82500. Moving to next.
# Trained fit 14650/82500. Moving to next.
# Trained fit 14700/82500. Moving to next.
# Trained fit 14750/82500. Moving to next.
# Trained fit 14800/82500. Moving to next.
# Trained fit 14850/82500. Moving to next.
# Trained fit 14900/82500. Moving to next.
# Trained fit 14950/82500. Moving to next.
# Trained fit 15000/82500. Moving to next.
# Trained fit 15050/82500. Moving to next.
# Trained fit 15100/82500. Moving to next.
# Trained fit 15150/82500. Moving to next.
# Trained fit 15200/82500. Moving to next.
# Trained fit 15250/82500. Moving to next.
# Trained fit 15300/82500. Moving to next.
# Trained fit 15350/82500. Moving to next.
# Trained fit 15400/82500. Moving to next.
# Trained fit 15450/82500. Moving to next.
# Trained fit 15500/82500. Moving to next.
# Trained fit 15550/82500. Moving to next.
# Trained fit 15600/82500. Moving to next.
# Trained fit 15650/82500. Moving to next.
# Trained fit 15700/82500. Moving to next.
# Trained fit 15750/82500. Moving to next.
# Trained fit 15800/82500. Moving to next.
# Trained fit 15850/82500. Moving to next.
# Trained fit 15900/82500. Moving to next.
# Trained fit 15950/82500. Moving to next.
# Trained fit 16000/82500. Moving to next.
# Trained fit 16050/82500. Moving to next.
# Trained fit 16100/82500. Moving to next.
# Trained fit 16150/82500. Moving to next.
# Trained fit 16200/82500. Moving to next.
# Trained fit 16250/82500. Moving to next.
# Trained fit 16300/82500. Moving to next.
# Trained fit 16350/82500. Moving to next.
# Trained fit 16400/82500. Moving to next.
# Trained fit 16450/82500. Moving to next.
# Trained fit 16500/82500. Moving to next.
# Trained fit 16550/82500. Moving to next.
# Trained fit 16600/82500. Moving to next.
# Trained fit 16650/82500. Moving to next.
# Trained fit 16700/82500. Moving to next.
# Trained fit 16750/82500. Moving to next.
# Trained fit 16800/82500. Moving to next.
# Trained fit 16850/82500. Moving to next.
# Trained fit 16900/82500. Moving to next.
# Trained fit 16950/82500. Moving to next.
# Trained fit 17000/82500. Moving to next.
# Trained fit 17050/82500. Moving to next.
# Trained fit 17100/82500. Moving to next.
# Trained fit 17150/82500. Moving to next.
# Trained fit 17200/82500. Moving to next.
# Trained fit 17250/82500. Moving to next.
# Trained fit 17300/82500. Moving to next.
# Trained fit 17350/82500. Moving to next.
# Trained fit 17400/82500. Moving to next.
# Trained fit 17450/82500. Moving to next.
# Trained fit 17500/82500. Moving to next.
# Trained fit 17550/82500. Moving to next.
# Trained fit 17600/82500. Moving to next.
# Trained fit 17650/82500. Moving to next.
# Trained fit 17700/82500. Moving to next.
# Trained fit 17750/82500. Moving to next.
# Trained fit 17800/82500. Moving to next.
# Trained fit 17850/82500. Moving to next.
# Trained fit 17900/82500. Moving to next.
# Trained fit 17950/82500. Moving to next.
# Trained fit 18000/82500. Moving to next.
# Trained fit 18050/82500. Moving to next.
# Trained fit 18100/82500. Moving to next.
# Trained fit 18150/82500. Moving to next.
# Trained fit 18200/82500. Moving to next.
# Trained fit 18250/82500. Moving to next.
# Trained fit 18300/82500. Moving to next.
# Trained fit 18350/82500. Moving to next.
# Trained fit 18400/82500. Moving to next.
# Trained fit 18450/82500. Moving to next.
# Trained fit 18500/82500. Moving to next.
# Trained fit 18550/82500. Moving to next.
# Trained fit 18600/82500. Moving to next.
# Trained fit 18650/82500. Moving to next.
# Trained fit 18700/82500. Moving to next.
# Trained fit 18750/82500. Moving to next.
# Trained fit 18800/82500. Moving to next.
# Trained fit 18850/82500. Moving to next.
# Trained fit 18900/82500. Moving to next.
# Trained fit 18950/82500. Moving to next.
# Trained fit 19000/82500. Moving to next.
# Trained fit 19050/82500. Moving to next.
# Trained fit 19100/82500. Moving to next.
# Trained fit 19150/82500. Moving to next.
# Trained fit 19200/82500. Moving to next.
# Trained fit 19250/82500. Moving to next.
# Trained fit 19300/82500. Moving to next.
# Trained fit 19350/82500. Moving to next.
# Trained fit 19400/82500. Moving to next.
# Trained fit 19450/82500. Moving to next.
# Trained fit 19500/82500. Moving to next.
# Trained fit 19550/82500. Moving to next.
# Trained fit 19600/82500. Moving to next.
# Trained fit 19650/82500. Moving to next.
# Trained fit 19700/82500. Moving to next.
# Trained fit 19750/82500. Moving to next.
# Trained fit 19800/82500. Moving to next.
# Trained fit 19850/82500. Moving to next.
# Trained fit 19900/82500. Moving to next.
# Trained fit 19950/82500. Moving to next.
# Trained fit 20000/82500. Moving to next.
# Trained fit 20050/82500. Moving to next.
# Trained fit 20100/82500. Moving to next.
# Trained fit 20150/82500. Moving to next.
# Trained fit 20200/82500. Moving to next.
# Trained fit 20250/82500. Moving to next.
# Trained fit 20300/82500. Moving to next.
# Trained fit 20350/82500. Moving to next.
# Trained fit 20400/82500. Moving to next.
# Trained fit 20450/82500. Moving to next.
# Trained fit 20500/82500. Moving to next.
# Trained fit 20550/82500. Moving to next.
# Trained fit 20600/82500. Moving to next.
# Trained fit 20650/82500. Moving to next.
# Trained fit 20700/82500. Moving to next.
# Trained fit 20750/82500. Moving to next.
# Trained fit 20800/82500. Moving to next.
# Trained fit 20850/82500. Moving to next.
# Trained fit 20900/82500. Moving to next.
# Trained fit 20950/82500. Moving to next.
# Trained fit 21000/82500. Moving to next.
# Trained fit 21050/82500. Moving to next.
# Trained fit 21100/82500. Moving to next.
# Trained fit 21150/82500. Moving to next.
# Trained fit 21200/82500. Moving to next.
# Trained fit 21250/82500. Moving to next.
# Trained fit 21300/82500. Moving to next.
# Trained fit 21350/82500. Moving to next.
# Trained fit 21400/82500. Moving to next.
# Trained fit 21450/82500. Moving to next.
# Trained fit 21500/82500. Moving to next.
# Trained fit 21550/82500. Moving to next.
# Trained fit 21600/82500. Moving to next.
# Trained fit 21650/82500. Moving to next.
# Trained fit 21700/82500. Moving to next.
# Trained fit 21750/82500. Moving to next.
# Trained fit 21800/82500. Moving to next.
# Trained fit 21850/82500. Moving to next.
# Trained fit 21900/82500. Moving to next.
# Trained fit 21950/82500. Moving to next.
# Trained fit 22000/82500. Moving to next.
# Trained fit 22050/82500. Moving to next.
# Trained fit 22100/82500. Moving to next.
# Trained fit 22150/82500. Moving to next.
# Trained fit 22200/82500. Moving to next.
# Trained fit 22250/82500. Moving to next.
# Trained fit 22300/82500. Moving to next.
# Trained fit 22350/82500. Moving to next.
# Trained fit 22400/82500. Moving to next.
# Trained fit 22450/82500. Moving to next.
# Trained fit 22500/82500. Moving to next.
# Trained fit 22550/82500. Moving to next.
# Trained fit 22600/82500. Moving to next.
# Trained fit 22650/82500. Moving to next.
# Trained fit 22700/82500. Moving to next.
# Trained fit 22750/82500. Moving to next.
# Trained fit 22800/82500. Moving to next.
# Trained fit 22850/82500. Moving to next.
# Trained fit 22900/82500. Moving to next.
# Trained fit 22950/82500. Moving to next.
# Trained fit 23000/82500. Moving to next.
# Trained fit 23050/82500. Moving to next.
# Trained fit 23100/82500. Moving to next.
# Trained fit 23150/82500. Moving to next.
# Trained fit 23200/82500. Moving to next.
# Trained fit 23250/82500. Moving to next.
# Trained fit 23300/82500. Moving to next.
# Trained fit 23350/82500. Moving to next.
# Trained fit 23400/82500. Moving to next.
# Trained fit 23450/82500. Moving to next.
# Trained fit 23500/82500. Moving to next.
# Trained fit 23550/82500. Moving to next.
# Trained fit 23600/82500. Moving to next.
# Trained fit 23650/82500. Moving to next.
# Trained fit 23700/82500. Moving to next.
# Trained fit 23750/82500. Moving to next.
# Trained fit 23800/82500. Moving to next.
# Trained fit 23850/82500. Moving to next.
# Trained fit 23900/82500. Moving to next.
# Trained fit 23950/82500. Moving to next.
# Trained fit 24000/82500. Moving to next.
# Trained fit 24050/82500. Moving to next.
# Trained fit 24100/82500. Moving to next.
# Trained fit 24150/82500. Moving to next.
# Trained fit 24200/82500. Moving to next.
# Trained fit 24250/82500. Moving to next.
# Trained fit 24300/82500. Moving to next.
# Trained fit 24350/82500. Moving to next.
# Trained fit 24400/82500. Moving to next.
# Trained fit 24450/82500. Moving to next.
# Trained fit 24500/82500. Moving to next.
# Trained fit 24550/82500. Moving to next.
# Trained fit 24600/82500. Moving to next.
# Trained fit 24650/82500. Moving to next.
# Trained fit 24700/82500. Moving to next.
# Trained fit 24750/82500. Moving to next.
# Trained fit 24800/82500. Moving to next.
# Trained fit 24850/82500. Moving to next.
# Trained fit 24900/82500. Moving to next.
# Trained fit 24950/82500. Moving to next.
# Trained fit 25000/82500. Moving to next.
# Trained fit 25050/82500. Moving to next.
# Trained fit 25100/82500. Moving to next.
# Trained fit 25150/82500. Moving to next.
# Trained fit 25200/82500. Moving to next.
# Trained fit 25250/82500. Moving to next.
# Trained fit 25300/82500. Moving to next.
# Trained fit 25350/82500. Moving to next.
# Trained fit 25400/82500. Moving to next.
# Trained fit 25450/82500. Moving to next.
# Trained fit 25500/82500. Moving to next.
# Trained fit 25550/82500. Moving to next.
# Trained fit 25600/82500. Moving to next.
# Trained fit 25650/82500. Moving to next.
# Trained fit 25700/82500. Moving to next.
# Trained fit 25750/82500. Moving to next.
# Trained fit 25800/82500. Moving to next.
# Trained fit 25850/82500. Moving to next.
# Trained fit 25900/82500. Moving to next.
# Trained fit 25950/82500. Moving to next.
# Trained fit 26000/82500. Moving to next.
# Trained fit 26050/82500. Moving to next.
# Trained fit 26100/82500. Moving to next.
# Trained fit 26150/82500. Moving to next.
# Trained fit 26200/82500. Moving to next.
# Trained fit 26250/82500. Moving to next.
# Trained fit 26300/82500. Moving to next.
# Trained fit 26350/82500. Moving to next.
# Trained fit 26400/82500. Moving to next.
# Trained fit 26450/82500. Moving to next.
# Trained fit 26500/82500. Moving to next.
# Trained fit 26550/82500. Moving to next.
# Trained fit 26600/82500. Moving to next.
# Trained fit 26650/82500. Moving to next.
# Trained fit 26700/82500. Moving to next.
# Trained fit 26750/82500. Moving to next.
# Trained fit 26800/82500. Moving to next.
# Trained fit 26850/82500. Moving to next.
# Trained fit 26900/82500. Moving to next.
# Trained fit 26950/82500. Moving to next.
# Trained fit 27000/82500. Moving to next.
# Trained fit 27050/82500. Moving to next.
# Trained fit 27100/82500. Moving to next.
# Trained fit 27150/82500. Moving to next.
# Trained fit 27200/82500. Moving to next.
# Trained fit 27250/82500. Moving to next.
# Trained fit 27300/82500. Moving to next.
# Trained fit 27350/82500. Moving to next.
# Trained fit 27400/82500. Moving to next.
# Trained fit 27450/82500. Moving to next.
# Trained fit 27500/82500. Moving to next.
# Trained fit 27550/82500. Moving to next.
# Trained fit 27600/82500. Moving to next.
# Trained fit 27650/82500. Moving to next.
# Trained fit 27700/82500. Moving to next.
# Trained fit 27750/82500. Moving to next.
# Trained fit 27800/82500. Moving to next.
# Trained fit 27850/82500. Moving to next.
# Trained fit 27900/82500. Moving to next.
# Trained fit 27950/82500. Moving to next.
# Trained fit 28000/82500. Moving to next.
# Trained fit 28050/82500. Moving to next.
# Trained fit 28100/82500. Moving to next.
# Trained fit 28150/82500. Moving to next.
# Trained fit 28200/82500. Moving to next.
# Trained fit 28250/82500. Moving to next.
# Trained fit 28300/82500. Moving to next.
# Trained fit 28350/82500. Moving to next.
# Trained fit 28400/82500. Moving to next.
# Trained fit 28450/82500. Moving to next.
# Trained fit 28500/82500. Moving to next.
# Trained fit 28550/82500. Moving to next.
# Trained fit 28600/82500. Moving to next.
# Trained fit 28650/82500. Moving to next.
# Trained fit 28700/82500. Moving to next.
# Trained fit 28750/82500. Moving to next.
# Trained fit 28800/82500. Moving to next.
# Trained fit 28850/82500. Moving to next.
# Trained fit 28900/82500. Moving to next.
# Trained fit 28950/82500. Moving to next.
# Trained fit 29000/82500. Moving to next.
# Trained fit 29050/82500. Moving to next.
# Trained fit 29100/82500. Moving to next.
# Trained fit 29150/82500. Moving to next.
# Trained fit 29200/82500. Moving to next.
# Trained fit 29250/82500. Moving to next.
# Trained fit 29300/82500. Moving to next.
# Trained fit 29350/82500. Moving to next.
# Trained fit 29400/82500. Moving to next.
# Trained fit 29450/82500. Moving to next.
# Trained fit 29500/82500. Moving to next.
# Trained fit 29550/82500. Moving to next.
# Trained fit 29600/82500. Moving to next.
# Trained fit 29650/82500. Moving to next.
# Trained fit 29700/82500. Moving to next.
# Trained fit 29750/82500. Moving to next.
# Trained fit 29800/82500. Moving to next.
# Trained fit 29850/82500. Moving to next.
# Trained fit 29900/82500. Moving to next.
# Trained fit 29950/82500. Moving to next.
# Trained fit 30000/82500. Moving to next.
# Trained fit 30050/82500. Moving to next.
# Trained fit 30100/82500. Moving to next.
# Trained fit 30150/82500. Moving to next.
# Trained fit 30200/82500. Moving to next.
# Trained fit 30250/82500. Moving to next.
# Trained fit 30300/82500. Moving to next.
# Trained fit 30350/82500. Moving to next.
# Trained fit 30400/82500. Moving to next.
# Trained fit 30450/82500. Moving to next.
# Trained fit 30500/82500. Moving to next.
# Trained fit 30550/82500. Moving to next.
# Trained fit 30600/82500. Moving to next.
# Trained fit 30650/82500. Moving to next.
# Trained fit 30700/82500. Moving to next.
# Trained fit 30750/82500. Moving to next.
# Trained fit 30800/82500. Moving to next.
# Trained fit 30850/82500. Moving to next.
# Trained fit 30900/82500. Moving to next.
# Trained fit 30950/82500. Moving to next.
# Trained fit 31000/82500. Moving to next.
# Trained fit 31050/82500. Moving to next.
# Trained fit 31100/82500. Moving to next.
# Trained fit 31150/82500. Moving to next.
# Trained fit 31200/82500. Moving to next.
# Trained fit 31250/82500. Moving to next.
# Trained fit 31300/82500. Moving to next.
# Trained fit 31350/82500. Moving to next.
# Trained fit 31400/82500. Moving to next.
# Trained fit 31450/82500. Moving to next.
# Trained fit 31500/82500. Moving to next.
# Trained fit 31550/82500. Moving to next.
# Trained fit 31600/82500. Moving to next.
# Trained fit 31650/82500. Moving to next.
# Trained fit 31700/82500. Moving to next.
# Trained fit 31750/82500. Moving to next.
# Trained fit 31800/82500. Moving to next.
# Trained fit 31850/82500. Moving to next.
# Trained fit 31900/82500. Moving to next.
# Trained fit 31950/82500. Moving to next.
# Trained fit 32000/82500. Moving to next.
# Trained fit 32050/82500. Moving to next.
# Trained fit 32100/82500. Moving to next.
# Trained fit 32150/82500. Moving to next.
# Trained fit 32200/82500. Moving to next.
# Trained fit 32250/82500. Moving to next.
# Trained fit 32300/82500. Moving to next.
# Trained fit 32350/82500. Moving to next.
# Trained fit 32400/82500. Moving to next.
# Trained fit 32450/82500. Moving to next.
# Trained fit 32500/82500. Moving to next.
# Trained fit 32550/82500. Moving to next.
# Trained fit 32600/82500. Moving to next.
# Trained fit 32650/82500. Moving to next.
# Trained fit 32700/82500. Moving to next.
# Trained fit 32750/82500. Moving to next.
# Trained fit 32800/82500. Moving to next.
# Trained fit 32850/82500. Moving to next.
# Trained fit 32900/82500. Moving to next.
# Trained fit 32950/82500. Moving to next.
# Trained fit 33000/82500. Moving to next.
# Trained fit 33050/82500. Moving to next.
# Trained fit 33100/82500. Moving to next.
# Trained fit 33150/82500. Moving to next.
# Trained fit 33200/82500. Moving to next.
# Trained fit 33250/82500. Moving to next.
# Trained fit 33300/82500. Moving to next.
# Trained fit 33350/82500. Moving to next.
# Trained fit 33400/82500. Moving to next.
# Trained fit 33450/82500. Moving to next.
# Trained fit 33500/82500. Moving to next.
# Trained fit 33550/82500. Moving to next.
# Trained fit 33600/82500. Moving to next.
# Trained fit 33650/82500. Moving to next.
# Trained fit 33700/82500. Moving to next.
# Trained fit 33750/82500. Moving to next.
# Trained fit 33800/82500. Moving to next.
# Trained fit 33850/82500. Moving to next.
# Trained fit 33900/82500. Moving to next.
# Trained fit 33950/82500. Moving to next.
# Trained fit 34000/82500. Moving to next.
# Trained fit 34050/82500. Moving to next.
# Trained fit 34100/82500. Moving to next.
# Trained fit 34150/82500. Moving to next.
# Trained fit 34200/82500. Moving to next.
# Trained fit 34250/82500. Moving to next.
# Trained fit 34300/82500. Moving to next.
# Trained fit 34350/82500. Moving to next.
# Trained fit 34400/82500. Moving to next.
# Trained fit 34450/82500. Moving to next.
# Trained fit 34500/82500. Moving to next.
# Trained fit 34550/82500. Moving to next.
# Trained fit 34600/82500. Moving to next.
# Trained fit 34650/82500. Moving to next.
# Trained fit 34700/82500. Moving to next.
# Trained fit 34750/82500. Moving to next.
# Trained fit 34800/82500. Moving to next.
# Trained fit 34850/82500. Moving to next.
# Trained fit 34900/82500. Moving to next.
# Trained fit 34950/82500. Moving to next.
# Trained fit 35000/82500. Moving to next.
# Trained fit 35050/82500. Moving to next.
# Trained fit 35100/82500. Moving to next.
# Trained fit 35150/82500. Moving to next.
# Trained fit 35200/82500. Moving to next.
# Trained fit 35250/82500. Moving to next.
# Trained fit 35300/82500. Moving to next.
# Trained fit 35350/82500. Moving to next.
# Trained fit 35400/82500. Moving to next.
# Trained fit 35450/82500. Moving to next.
# Trained fit 35500/82500. Moving to next.
# Trained fit 35550/82500. Moving to next.
# Trained fit 35600/82500. Moving to next.
# Trained fit 35650/82500. Moving to next.
# Trained fit 35700/82500. Moving to next.
# Trained fit 35750/82500. Moving to next.
# Trained fit 35800/82500. Moving to next.
# Trained fit 35850/82500. Moving to next.
# Trained fit 35900/82500. Moving to next.
# Trained fit 35950/82500. Moving to next.
# Trained fit 36000/82500. Moving to next.
# Trained fit 36050/82500. Moving to next.
# Trained fit 36100/82500. Moving to next.
# Trained fit 36150/82500. Moving to next.
# Trained fit 36200/82500. Moving to next.
# Trained fit 36250/82500. Moving to next.
# Trained fit 36300/82500. Moving to next.
# Trained fit 36350/82500. Moving to next.
# Trained fit 36400/82500. Moving to next.
# Trained fit 36450/82500. Moving to next.
# Trained fit 36500/82500. Moving to next.
# Trained fit 36550/82500. Moving to next.
# Trained fit 36600/82500. Moving to next.
# Trained fit 36650/82500. Moving to next.
# Trained fit 36700/82500. Moving to next.
# Trained fit 36750/82500. Moving to next.
# Trained fit 36800/82500. Moving to next.
# Trained fit 36850/82500. Moving to next.
# Trained fit 36900/82500. Moving to next.
# Trained fit 36950/82500. Moving to next.
# Trained fit 37000/82500. Moving to next.
# Trained fit 37050/82500. Moving to next.
# Trained fit 37100/82500. Moving to next.
# Trained fit 37150/82500. Moving to next.
# Trained fit 37200/82500. Moving to next.
# Trained fit 37250/82500. Moving to next.
# Trained fit 37300/82500. Moving to next.
# Trained fit 37350/82500. Moving to next.
# Trained fit 37400/82500. Moving to next.
# Trained fit 37450/82500. Moving to next.
# Trained fit 37500/82500. Moving to next.
# Trained fit 37550/82500. Moving to next.
# Trained fit 37600/82500. Moving to next.
# Trained fit 37650/82500. Moving to next.
# Trained fit 37700/82500. Moving to next.
# Trained fit 37750/82500. Moving to next.
# Trained fit 37800/82500. Moving to next.
# Trained fit 37850/82500. Moving to next.
# Trained fit 37900/82500. Moving to next.
# Trained fit 37950/82500. Moving to next.
# Trained fit 38000/82500. Moving to next.
# Trained fit 38050/82500. Moving to next.
# Trained fit 38100/82500. Moving to next.
# Trained fit 38150/82500. Moving to next.
# Trained fit 38200/82500. Moving to next.
# Trained fit 38250/82500. Moving to next.
# Trained fit 38300/82500. Moving to next.
# Trained fit 38350/82500. Moving to next.
# Trained fit 38400/82500. Moving to next.
# Trained fit 38450/82500. Moving to next.
# Trained fit 38500/82500. Moving to next.
# Trained fit 38550/82500. Moving to next.
# Trained fit 38600/82500. Moving to next.
# Trained fit 38650/82500. Moving to next.
# Trained fit 38700/82500. Moving to next.
# Trained fit 38750/82500. Moving to next.
# Trained fit 38800/82500. Moving to next.
# Trained fit 38850/82500. Moving to next.
# Trained fit 38900/82500. Moving to next.
# Trained fit 38950/82500. Moving to next.
# Trained fit 39000/82500. Moving to next.
# Trained fit 39050/82500. Moving to next.
# Trained fit 39100/82500. Moving to next.
# Trained fit 39150/82500. Moving to next.
# Trained fit 39200/82500. Moving to next.
# Trained fit 39250/82500. Moving to next.
# Trained fit 39300/82500. Moving to next.
# Trained fit 39350/82500. Moving to next.
# Trained fit 39400/82500. Moving to next.
# Trained fit 39450/82500. Moving to next.
# Trained fit 39500/82500. Moving to next.
# Trained fit 39550/82500. Moving to next.
# Trained fit 39600/82500. Moving to next.
# Trained fit 39650/82500. Moving to next.
# Trained fit 39700/82500. Moving to next.
# Trained fit 39750/82500. Moving to next.
# Trained fit 39800/82500. Moving to next.
# Trained fit 39850/82500. Moving to next.
# Trained fit 39900/82500. Moving to next.
# Trained fit 39950/82500. Moving to next.
# Trained fit 40000/82500. Moving to next.
# Trained fit 40050/82500. Moving to next.
# Trained fit 40100/82500. Moving to next.
# Trained fit 40150/82500. Moving to next.
# Trained fit 40200/82500. Moving to next.
# Trained fit 40250/82500. Moving to next.
# Trained fit 40300/82500. Moving to next.
# Trained fit 40350/82500. Moving to next.
# Trained fit 40400/82500. Moving to next.
# Trained fit 40450/82500. Moving to next.
# Trained fit 40500/82500. Moving to next.
# Trained fit 40550/82500. Moving to next.
# Trained fit 40600/82500. Moving to next.
# Trained fit 40650/82500. Moving to next.
# Trained fit 40700/82500. Moving to next.
# Trained fit 40750/82500. Moving to next.
# Trained fit 40800/82500. Moving to next.
# Trained fit 40850/82500. Moving to next.
# Trained fit 40900/82500. Moving to next.
# Trained fit 40950/82500. Moving to next.
# Trained fit 41000/82500. Moving to next.
# Trained fit 41050/82500. Moving to next.
# Trained fit 41100/82500. Moving to next.
# Trained fit 41150/82500. Moving to next.
# Trained fit 41200/82500. Moving to next.
# Trained fit 41250/82500. Moving to next.
# Trained fit 41300/82500. Moving to next.
# Trained fit 41350/82500. Moving to next.
# Trained fit 41400/82500. Moving to next.
# Trained fit 41450/82500. Moving to next.
# Trained fit 41500/82500. Moving to next.
# Trained fit 41550/82500. Moving to next.
# Trained fit 41600/82500. Moving to next.
# Trained fit 41650/82500. Moving to next.
# Trained fit 41700/82500. Moving to next.
# Trained fit 41750/82500. Moving to next.
# Trained fit 41800/82500. Moving to next.
# Trained fit 41850/82500. Moving to next.
# Trained fit 41900/82500. Moving to next.
# Trained fit 41950/82500. Moving to next.
# Trained fit 42000/82500. Moving to next.
# Trained fit 42050/82500. Moving to next.
# Trained fit 42100/82500. Moving to next.
# Trained fit 42150/82500. Moving to next.
# Trained fit 42200/82500. Moving to next.
# Trained fit 42250/82500. Moving to next.
# Trained fit 42300/82500. Moving to next.
# Trained fit 42350/82500. Moving to next.
# Trained fit 42400/82500. Moving to next.
# Trained fit 42450/82500. Moving to next.
# Trained fit 42500/82500. Moving to next.
# Trained fit 42550/82500. Moving to next.
# Trained fit 42600/82500. Moving to next.
# Trained fit 42650/82500. Moving to next.
# Trained fit 42700/82500. Moving to next.
# Trained fit 42750/82500. Moving to next.
# Trained fit 42800/82500. Moving to next.
# Trained fit 42850/82500. Moving to next.
# Trained fit 42900/82500. Moving to next.
# Trained fit 42950/82500. Moving to next.
# Trained fit 43000/82500. Moving to next.
# Trained fit 43050/82500. Moving to next.
# Trained fit 43100/82500. Moving to next.
# Trained fit 43150/82500. Moving to next.
# Trained fit 43200/82500. Moving to next.
# Trained fit 43250/82500. Moving to next.
# Trained fit 43300/82500. Moving to next.
# Trained fit 43350/82500. Moving to next.
# Trained fit 43400/82500. Moving to next.
# Trained fit 43450/82500. Moving to next.
# Trained fit 43500/82500. Moving to next.
# Trained fit 43550/82500. Moving to next.
# Trained fit 43600/82500. Moving to next.
# Trained fit 43650/82500. Moving to next.
# Trained fit 43700/82500. Moving to next.
# Trained fit 43750/82500. Moving to next.
# Trained fit 43800/82500. Moving to next.
# Trained fit 43850/82500. Moving to next.
# Trained fit 43900/82500. Moving to next.
# Trained fit 43950/82500. Moving to next.
# Trained fit 44000/82500. Moving to next.
# Trained fit 44050/82500. Moving to next.
# Trained fit 44100/82500. Moving to next.
# Trained fit 44150/82500. Moving to next.
# Trained fit 44200/82500. Moving to next.
# Trained fit 44250/82500. Moving to next.
# Trained fit 44300/82500. Moving to next.
# Trained fit 44350/82500. Moving to next.
# Trained fit 44400/82500. Moving to next.
# Trained fit 44450/82500. Moving to next.
# Trained fit 44500/82500. Moving to next.
# Trained fit 44550/82500. Moving to next.
# Trained fit 44600/82500. Moving to next.
# Trained fit 44650/82500. Moving to next.
# Trained fit 44700/82500. Moving to next.
# Trained fit 44750/82500. Moving to next.
# Trained fit 44800/82500. Moving to next.
# Trained fit 44850/82500. Moving to next.
# Trained fit 44900/82500. Moving to next.
# Trained fit 44950/82500. Moving to next.
# Trained fit 45000/82500. Moving to next.
# Trained fit 45050/82500. Moving to next.
# Trained fit 45100/82500. Moving to next.
# Trained fit 45150/82500. Moving to next.
# Trained fit 45200/82500. Moving to next.
# Trained fit 45250/82500. Moving to next.
# Trained fit 45300/82500. Moving to next.
# Trained fit 45350/82500. Moving to next.
# Trained fit 45400/82500. Moving to next.
# Trained fit 45450/82500. Moving to next.
# Trained fit 45500/82500. Moving to next.
# Trained fit 45550/82500. Moving to next.
# Trained fit 45600/82500. Moving to next.
# Trained fit 45650/82500. Moving to next.
# Trained fit 45700/82500. Moving to next.
# Trained fit 45750/82500. Moving to next.
# Trained fit 45800/82500. Moving to next.
# Trained fit 45850/82500. Moving to next.
# Trained fit 45900/82500. Moving to next.
# Trained fit 45950/82500. Moving to next.
# Trained fit 46000/82500. Moving to next.
# Trained fit 46050/82500. Moving to next.
# Trained fit 46100/82500. Moving to next.
# Trained fit 46150/82500. Moving to next.
# Trained fit 46200/82500. Moving to next.
# Trained fit 46250/82500. Moving to next.
# Trained fit 46300/82500. Moving to next.
# Trained fit 46350/82500. Moving to next.
# Trained fit 46400/82500. Moving to next.
# Trained fit 46450/82500. Moving to next.
# Trained fit 46500/82500. Moving to next.
# Trained fit 46550/82500. Moving to next.
# Trained fit 46600/82500. Moving to next.
# Trained fit 46650/82500. Moving to next.
# Trained fit 46700/82500. Moving to next.
# Trained fit 46750/82500. Moving to next.
# Trained fit 46800/82500. Moving to next.
# Trained fit 46850/82500. Moving to next.
# Trained fit 46900/82500. Moving to next.
# Trained fit 46950/82500. Moving to next.
# Trained fit 47000/82500. Moving to next.
# Trained fit 47050/82500. Moving to next.
# Trained fit 47100/82500. Moving to next.
# Trained fit 47150/82500. Moving to next.
# Trained fit 47200/82500. Moving to next.
# Trained fit 47250/82500. Moving to next.
# Trained fit 47300/82500. Moving to next.
# Trained fit 47350/82500. Moving to next.
# Trained fit 47400/82500. Moving to next.
# Trained fit 47450/82500. Moving to next.
# Trained fit 47500/82500. Moving to next.
# Trained fit 47550/82500. Moving to next.
# Trained fit 47600/82500. Moving to next.
# Trained fit 47650/82500. Moving to next.
# Trained fit 47700/82500. Moving to next.
# Trained fit 47750/82500. Moving to next.
# Trained fit 47800/82500. Moving to next.
# Trained fit 47850/82500. Moving to next.
# Trained fit 47900/82500. Moving to next.
# Trained fit 47950/82500. Moving to next.
# Trained fit 48000/82500. Moving to next.
# Trained fit 48050/82500. Moving to next.
# Trained fit 48100/82500. Moving to next.
# Trained fit 48150/82500. Moving to next.
# Trained fit 48200/82500. Moving to next.
# Trained fit 48250/82500. Moving to next.
# Trained fit 48300/82500. Moving to next.
# Trained fit 48350/82500. Moving to next.
# Trained fit 48400/82500. Moving to next.
# Trained fit 48450/82500. Moving to next.
# Trained fit 48500/82500. Moving to next.
# Trained fit 48550/82500. Moving to next.
# Trained fit 48600/82500. Moving to next.
# Trained fit 48650/82500. Moving to next.
# Trained fit 48700/82500. Moving to next.
# Trained fit 48750/82500. Moving to next.
# Trained fit 48800/82500. Moving to next.
# Trained fit 48850/82500. Moving to next.
# Trained fit 48900/82500. Moving to next.
# Trained fit 48950/82500. Moving to next.
# Trained fit 49000/82500. Moving to next.
# Trained fit 49050/82500. Moving to next.
# Trained fit 49100/82500. Moving to next.
# Trained fit 49150/82500. Moving to next.
# Trained fit 49200/82500. Moving to next.
# Trained fit 49250/82500. Moving to next.
# Trained fit 49300/82500. Moving to next.
# Trained fit 49350/82500. Moving to next.
# Trained fit 49400/82500. Moving to next.
# Trained fit 49450/82500. Moving to next.
# Trained fit 49500/82500. Moving to next.
# Trained fit 49550/82500. Moving to next.
# Trained fit 49600/82500. Moving to next.
# Trained fit 49650/82500. Moving to next.
# Trained fit 49700/82500. Moving to next.
# Trained fit 49750/82500. Moving to next.
# Trained fit 49800/82500. Moving to next.
# Trained fit 49850/82500. Moving to next.
# Trained fit 49900/82500. Moving to next.
# Trained fit 49950/82500. Moving to next.
# Trained fit 50000/82500. Moving to next.
# Trained fit 50050/82500. Moving to next.
# Trained fit 50100/82500. Moving to next.
# Trained fit 50150/82500. Moving to next.
# Trained fit 50200/82500. Moving to next.
# Trained fit 50250/82500. Moving to next.
# Trained fit 50300/82500. Moving to next.
# Trained fit 50350/82500. Moving to next.
# Trained fit 50400/82500. Moving to next.
# Trained fit 50450/82500. Moving to next.
# Trained fit 50500/82500. Moving to next.
# Trained fit 50550/82500. Moving to next.
# Trained fit 50600/82500. Moving to next.
# Trained fit 50650/82500. Moving to next.
# Trained fit 50700/82500. Moving to next.
# Trained fit 50750/82500. Moving to next.
# Trained fit 50800/82500. Moving to next.
# Trained fit 50850/82500. Moving to next.
# Trained fit 50900/82500. Moving to next.
# Trained fit 50950/82500. Moving to next.
# Trained fit 51000/82500. Moving to next.
# Trained fit 51050/82500. Moving to next.
# Trained fit 51100/82500. Moving to next.
# Trained fit 51150/82500. Moving to next.
# Trained fit 51200/82500. Moving to next.
# Trained fit 51250/82500. Moving to next.
# Trained fit 51300/82500. Moving to next.
# Trained fit 51350/82500. Moving to next.
# Trained fit 51400/82500. Moving to next.
# Trained fit 51450/82500. Moving to next.
# Trained fit 51500/82500. Moving to next.
# Trained fit 51550/82500. Moving to next.
# Trained fit 51600/82500. Moving to next.
# Trained fit 51650/82500. Moving to next.
# Trained fit 51700/82500. Moving to next.
# Trained fit 51750/82500. Moving to next.
# Trained fit 51800/82500. Moving to next.
# Trained fit 51850/82500. Moving to next.
# Trained fit 51900/82500. Moving to next.
# Trained fit 51950/82500. Moving to next.
# Trained fit 52000/82500. Moving to next.
# Trained fit 52050/82500. Moving to next.
# Trained fit 52100/82500. Moving to next.
# Trained fit 52150/82500. Moving to next.
# Trained fit 52200/82500. Moving to next.
# Trained fit 52250/82500. Moving to next.
# Trained fit 52300/82500. Moving to next.
# Trained fit 52350/82500. Moving to next.
# Trained fit 52400/82500. Moving to next.
# Trained fit 52450/82500. Moving to next.
# Trained fit 52500/82500. Moving to next.
# Trained fit 52550/82500. Moving to next.
# Trained fit 52600/82500. Moving to next.
# Trained fit 52650/82500. Moving to next.
# Trained fit 52700/82500. Moving to next.
# Trained fit 52750/82500. Moving to next.
# Trained fit 52800/82500. Moving to next.
# Trained fit 52850/82500. Moving to next.
# Trained fit 52900/82500. Moving to next.
# Trained fit 52950/82500. Moving to next.
# Trained fit 53000/82500. Moving to next.
# Trained fit 53050/82500. Moving to next.
# Trained fit 53100/82500. Moving to next.
# Trained fit 53150/82500. Moving to next.
# Trained fit 53200/82500. Moving to next.
# Trained fit 53250/82500. Moving to next.
# Trained fit 53300/82500. Moving to next.
# Trained fit 53350/82500. Moving to next.
# Trained fit 53400/82500. Moving to next.
# Trained fit 53450/82500. Moving to next.
# Trained fit 53500/82500. Moving to next.
# Trained fit 53550/82500. Moving to next.
# Trained fit 53600/82500. Moving to next.
# Trained fit 53650/82500. Moving to next.
# Trained fit 53700/82500. Moving to next.
# Trained fit 53750/82500. Moving to next.
# Trained fit 53800/82500. Moving to next.
# Trained fit 53850/82500. Moving to next.
# Trained fit 53900/82500. Moving to next.
# Trained fit 53950/82500. Moving to next.
# Trained fit 54000/82500. Moving to next.
# Trained fit 54050/82500. Moving to next.
# Trained fit 54100/82500. Moving to next.
# Trained fit 54150/82500. Moving to next.
# Trained fit 54200/82500. Moving to next.
# Trained fit 54250/82500. Moving to next.
# Trained fit 54300/82500. Moving to next.
# Trained fit 54350/82500. Moving to next.
# Trained fit 54400/82500. Moving to next.
# Trained fit 54450/82500. Moving to next.
# Trained fit 54500/82500. Moving to next.
# Trained fit 54550/82500. Moving to next.
# Trained fit 54600/82500. Moving to next.
# Trained fit 54650/82500. Moving to next.
# Trained fit 54700/82500. Moving to next.
# Trained fit 54750/82500. Moving to next.
# Trained fit 54800/82500. Moving to next.
# Trained fit 54850/82500. Moving to next.
# Trained fit 54900/82500. Moving to next.
# Trained fit 54950/82500. Moving to next.
# Trained fit 55000/82500. Moving to next.
# Trained fit 55050/82500. Moving to next.
# Trained fit 55100/82500. Moving to next.
# Trained fit 55150/82500. Moving to next.
# Trained fit 55200/82500. Moving to next.
# Trained fit 55250/82500. Moving to next.
# Trained fit 55300/82500. Moving to next.
# Trained fit 55350/82500. Moving to next.
# Trained fit 55400/82500. Moving to next.
# Trained fit 55450/82500. Moving to next.
# Trained fit 55500/82500. Moving to next.
# Trained fit 55550/82500. Moving to next.
# Trained fit 55600/82500. Moving to next.
# Trained fit 55650/82500. Moving to next.
# Trained fit 55700/82500. Moving to next.
# Trained fit 55750/82500. Moving to next.
# Trained fit 55800/82500. Moving to next.
# Trained fit 55850/82500. Moving to next.
# Trained fit 55900/82500. Moving to next.
# Trained fit 55950/82500. Moving to next.
# Trained fit 56000/82500. Moving to next.
# Trained fit 56050/82500. Moving to next.
# Trained fit 56100/82500. Moving to next.
# Trained fit 56150/82500. Moving to next.
# Trained fit 56200/82500. Moving to next.
# Trained fit 56250/82500. Moving to next.
# Trained fit 56300/82500. Moving to next.
# Trained fit 56350/82500. Moving to next.
# Trained fit 56400/82500. Moving to next.
# Trained fit 56450/82500. Moving to next.
# Trained fit 56500/82500. Moving to next.
# Trained fit 56550/82500. Moving to next.
# Trained fit 56600/82500. Moving to next.
# Trained fit 56650/82500. Moving to next.
# Trained fit 56700/82500. Moving to next.
# Trained fit 56750/82500. Moving to next.
# Trained fit 56800/82500. Moving to next.
# Trained fit 56850/82500. Moving to next.
# Trained fit 56900/82500. Moving to next.
# Trained fit 56950/82500. Moving to next.
# Trained fit 57000/82500. Moving to next.
# Trained fit 57050/82500. Moving to next.
# Trained fit 57100/82500. Moving to next.
# Trained fit 57150/82500. Moving to next.
# Trained fit 57200/82500. Moving to next.
# Trained fit 57250/82500. Moving to next.
# Trained fit 57300/82500. Moving to next.
# Trained fit 57350/82500. Moving to next.
# Trained fit 57400/82500. Moving to next.
# Trained fit 57450/82500. Moving to next.
# Trained fit 57500/82500. Moving to next.
# Trained fit 57550/82500. Moving to next.
# Trained fit 57600/82500. Moving to next.
# Trained fit 57650/82500. Moving to next.
# Trained fit 57700/82500. Moving to next.
# Trained fit 57750/82500. Moving to next.
# Trained fit 57800/82500. Moving to next.
# Trained fit 57850/82500. Moving to next.
# Trained fit 57900/82500. Moving to next.
# Trained fit 57950/82500. Moving to next.
# Trained fit 58000/82500. Moving to next.
# Trained fit 58050/82500. Moving to next.
# Trained fit 58100/82500. Moving to next.
# Trained fit 58150/82500. Moving to next.
# Trained fit 58200/82500. Moving to next.
# Trained fit 58250/82500. Moving to next.
# Trained fit 58300/82500. Moving to next.
# Trained fit 58350/82500. Moving to next.
# Trained fit 58400/82500. Moving to next.
# Trained fit 58450/82500. Moving to next.
# Trained fit 58500/82500. Moving to next.
# Trained fit 58550/82500. Moving to next.
# Trained fit 58600/82500. Moving to next.
# Trained fit 58650/82500. Moving to next.
# Trained fit 58700/82500. Moving to next.
# Trained fit 58750/82500. Moving to next.
# Trained fit 58800/82500. Moving to next.
# ...
# Trained fit 63300/82500. Moving to next.
# Trained fit 63350/82500. Moving to next.
# Trained fit 63400/82500. Moving to next.
# Trained fit 63450/82500. Moving to next.
# Trained fit 63500/82500. Moving to next.
# Trained fit 63550/82500. Moving to next.
# Trained fit 63600/82500. Moving to next.
# Trained fit 63650/82500. Moving to next.
# Trained fit 63700/82500. Moving to next.
# Trained fit 63750/82500. Moving to next.
# Trained fit 63800/82500. Moving to next.
# Trained fit 63850/82500. Moving to next.
# Trained fit 63900/82500. Moving to next.
# Trained fit 63950/82500. Moving to next.
# Trained fit 64000/82500. Moving to next.
# Trained fit 64050/82500. Moving to next.
# Trained fit 64100/82500. Moving to next.
# Trained fit 64150/82500. Moving to next.
# Trained fit 64200/82500. Moving to next.
# Trained fit 64250/82500. Moving to next.
# Trained fit 64300/82500. Moving to next.
# Trained fit 64350/82500. Moving to next.
# Trained fit 64400/82500. Moving to next.
# Trained fit 64450/82500. Moving to next.
# Trained fit 64500/82500. Moving to next.
# Trained fit 64550/82500. Moving to next.
# Trained fit 64600/82500. Moving to next.
# Trained fit 64650/82500. Moving to next.
# Trained fit 64700/82500. Moving to next.
# Trained fit 64750/82500. Moving to next.
# Trained fit 64800/82500. Moving to next.
# Trained fit 64850/82500. Moving to next.
# Trained fit 64900/82500. Moving to next.
# Trained fit 64950/82500. Moving to next.
# Trained fit 65000/82500. Moving to next.
# Trained fit 65050/82500. Moving to next.
# Trained fit 65100/82500. Moving to next.
# Trained fit 65150/82500. Moving to next.
# Trained fit 65200/82500. Moving to next.
# Trained fit 65250/82500. Moving to next.
# Trained fit 65300/82500. Moving to next.
# Trained fit 65350/82500. Moving to next.
# Trained fit 65400/82500. Moving to next.
# Trained fit 65450/82500. Moving to next.
# Trained fit 65500/82500. Moving to next.
# Trained fit 65550/82500. Moving to next.
# Trained fit 65600/82500. Moving to next.
# Trained fit 65650/82500. Moving to next.
# Trained fit 65700/82500. Moving to next.
# Trained fit 65750/82500. Moving to next.
# Trained fit 65800/82500. Moving to next.
# Trained fit 65850/82500. Moving to next.
# Trained fit 65900/82500. Moving to next.
# Trained fit 65950/82500. Moving to next.
# Trained fit 66000/82500. Moving to next.
# Trained fit 66050/82500. Moving to next.
# Trained fit 66100/82500. Moving to next.
# Trained fit 66150/82500. Moving to next.
# Trained fit 66200/82500. Moving to next.
# Trained fit 66250/82500. Moving to next.
# Trained fit 66300/82500. Moving to next.
# Trained fit 66350/82500. Moving to next.
# Trained fit 66400/82500. Moving to next.
# Trained fit 66450/82500. Moving to next.
# Trained fit 66500/82500. Moving to next.
# Trained fit 66550/82500. Moving to next.
# Trained fit 66600/82500. Moving to next.
# Trained fit 66650/82500. Moving to next.
# Trained fit 66700/82500. Moving to next.
# Trained fit 66750/82500. Moving to next.
# Trained fit 66800/82500. Moving to next.
# Trained fit 66850/82500. Moving to next.
# Trained fit 66900/82500. Moving to next.
# Trained fit 66950/82500. Moving to next.
# Trained fit 67000/82500. Moving to next.
# Trained fit 67050/82500. Moving to next.
# Trained fit 67100/82500. Moving to next.
# Trained fit 67150/82500. Moving to next.
# Trained fit 67200/82500. Moving to next.
# Trained fit 67250/82500. Moving to next.
# Trained fit 67300/82500. Moving to next.
# Trained fit 67350/82500. Moving to next.
# Trained fit 67400/82500. Moving to next.
# Trained fit 67450/82500. Moving to next.
# Trained fit 67500/82500. Moving to next.
# Trained fit 67550/82500. Moving to next.
# Trained fit 67600/82500. Moving to next.
# Trained fit 67650/82500. Moving to next.
# Trained fit 67700/82500. Moving to next.
# Trained fit 67750/82500. Moving to next.
# Trained fit 67800/82500. Moving to next.
# Trained fit 67850/82500. Moving to next.
# Trained fit 67900/82500. Moving to next.
# Trained fit 67950/82500. Moving to next.
# Trained fit 68000/82500. Moving to next.
# Trained fit 68050/82500. Moving to next.
# Trained fit 68100/82500. Moving to next.
# Trained fit 68150/82500. Moving to next.
# Trained fit 68200/82500. Moving to next.
# Trained fit 68250/82500. Moving to next.
# Trained fit 68300/82500. Moving to next.
# Trained fit 68350/82500. Moving to next.
# Trained fit 68400/82500. Moving to next.
# Trained fit 68450/82500. Moving to next.
# Trained fit 68500/82500. Moving to next.
# Trained fit 68550/82500. Moving to next.
# Trained fit 68600/82500. Moving to next.
# Trained fit 68650/82500. Moving to next.
# Trained fit 68700/82500. Moving to next.
# Trained fit 68750/82500. Moving to next.
# Trained fit 68800/82500. Moving to next.
# Trained fit 68850/82500. Moving to next.
# Trained fit 68900/82500. Moving to next.
# Trained fit 68950/82500. Moving to next.
# Trained fit 69000/82500. Moving to next.
# Trained fit 69050/82500. Moving to next.
# Trained fit 69100/82500. Moving to next.
# Trained fit 69150/82500. Moving to next.
# Trained fit 69200/82500. Moving to next.
# Trained fit 69250/82500. Moving to next.
# Trained fit 69300/82500. Moving to next.
# Trained fit 69350/82500. Moving to next.
# Trained fit 69400/82500. Moving to next.
# Trained fit 69450/82500. Moving to next.
# Trained fit 69500/82500. Moving to next.
# Trained fit 69550/82500. Moving to next.
# Trained fit 69600/82500. Moving to next.
# Trained fit 69650/82500. Moving to next.
# Trained fit 69700/82500. Moving to next.
# Trained fit 69750/82500. Moving to next.
# Trained fit 69800/82500. Moving to next.
# Trained fit 69850/82500. Moving to next.
# Trained fit 69900/82500. Moving to next.
# Trained fit 69950/82500. Moving to next.
# Trained fit 70000/82500. Moving to next.
# Trained fit 70050/82500. Moving to next.
# Trained fit 70100/82500. Moving to next.
# Trained fit 70150/82500. Moving to next.
# Trained fit 70200/82500. Moving to next.
# Trained fit 70250/82500. Moving to next.
# Trained fit 70300/82500. Moving to next.
# Trained fit 70350/82500. Moving to next.
# Trained fit 70400/82500. Moving to next.
# Trained fit 70450/82500. Moving to next.
# Trained fit 70500/82500. Moving to next.
# Trained fit 70550/82500. Moving to next.
# Trained fit 70600/82500. Moving to next.
# Trained fit 70650/82500. Moving to next.
# Trained fit 70700/82500. Moving to next.
# Trained fit 70750/82500. Moving to next.
# Trained fit 70800/82500. Moving to next.
# Trained fit 70850/82500. Moving to next.
# Trained fit 70900/82500. Moving to next.
# Trained fit 70950/82500. Moving to next.
# Trained fit 71000/82500. Moving to next.
# Trained fit 71050/82500. Moving to next.
# Trained fit 71100/82500. Moving to next.
# Trained fit 71150/82500. Moving to next.
# Trained fit 71200/82500. Moving to next.
# Trained fit 71250/82500. Moving to next.
# Trained fit 71300/82500. Moving to next.
# Trained fit 71350/82500. Moving to next.
# Trained fit 71400/82500. Moving to next.
# Trained fit 71450/82500. Moving to next.
# Trained fit 71500/82500. Moving to next.
# Trained fit 71550/82500. Moving to next.
# Trained fit 71600/82500. Moving to next.
# Trained fit 71650/82500. Moving to next.
# Trained fit 71700/82500. Moving to next.
# Trained fit 71750/82500. Moving to next.
# Trained fit 71800/82500. Moving to next.
# Trained fit 71850/82500. Moving to next.
# Trained fit 71900/82500. Moving to next.
# Trained fit 71950/82500. Moving to next.
# Trained fit 72000/82500. Moving to next.
# Trained fit 72050/82500. Moving to next.
# Trained fit 72100/82500. Moving to next.
# Trained fit 72150/82500. Moving to next.
# Trained fit 72200/82500. Moving to next.
# Trained fit 72250/82500. Moving to next.
# Trained fit 72300/82500. Moving to next.
# Trained fit 72350/82500. Moving to next.
# Trained fit 72400/82500. Moving to next.
# Trained fit 72450/82500. Moving to next.
# Trained fit 72500/82500. Moving to next.
# Trained fit 72550/82500. Moving to next.
# Trained fit 72600/82500. Moving to next.
# Trained fit 72650/82500. Moving to next.
# Trained fit 72700/82500. Moving to next.
# Trained fit 72750/82500. Moving to next.
# Trained fit 72800/82500. Moving to next.
# Trained fit 72850/82500. Moving to next.
# Trained fit 72900/82500. Moving to next.
# Trained fit 72950/82500. Moving to next.
# Trained fit 73000/82500. Moving to next.
# Trained fit 73050/82500. Moving to next.
# Trained fit 73100/82500. Moving to next.
# Trained fit 73150/82500. Moving to next.
# Trained fit 73200/82500. Moving to next.
# Trained fit 73250/82500. Moving to next.
# Trained fit 73300/82500. Moving to next.
# Trained fit 73350/82500. Moving to next.
# Trained fit 73400/82500. Moving to next.
# Trained fit 73450/82500. Moving to next.
# Trained fit 73500/82500. Moving to next.
# Trained fit 73550/82500. Moving to next.
# Trained fit 73600/82500. Moving to next.
# Trained fit 73650/82500. Moving to next.
# Trained fit 73700/82500. Moving to next.
# Trained fit 73750/82500. Moving to next.
# Trained fit 73800/82500. Moving to next.
# Trained fit 73850/82500. Moving to next.
# Trained fit 73900/82500. Moving to next.
# Trained fit 73950/82500. Moving to next.
# Trained fit 74000/82500. Moving to next.
# Trained fit 74050/82500. Moving to next.
# Trained fit 74100/82500. Moving to next.
# Trained fit 74150/82500. Moving to next.
# Trained fit 74200/82500. Moving to next.
# Trained fit 74250/82500. Moving to next.
# Trained fit 74300/82500. Moving to next.
# Trained fit 74350/82500. Moving to next.
# Trained fit 74400/82500. Moving to next.
# Trained fit 74450/82500. Moving to next.
# Trained fit 74500/82500. Moving to next.
# Trained fit 74550/82500. Moving to next.
# Trained fit 74600/82500. Moving to next.
# Trained fit 74650/82500. Moving to next.
# Trained fit 74700/82500. Moving to next.
# Trained fit 74750/82500. Moving to next.
# Trained fit 74800/82500. Moving to next.
# Trained fit 74850/82500. Moving to next.
# Trained fit 74900/82500. Moving to next.
# Trained fit 74950/82500. Moving to next.
# Trained fit 75000/82500. Moving to next.
# Trained fit 75050/82500. Moving to next.
# Trained fit 75100/82500. Moving to next.
# Trained fit 75150/82500. Moving to next.
# Trained fit 75200/82500. Moving to next.
# Trained fit 75250/82500. Moving to next.
# Trained fit 75300/82500. Moving to next.
# Trained fit 75350/82500. Moving to next.
# Trained fit 75400/82500. Moving to next.
# Trained fit 75450/82500. Moving to next.
# Trained fit 75500/82500. Moving to next.
# Trained fit 75550/82500. Moving to next.
# Trained fit 75600/82500. Moving to next.
# Trained fit 75650/82500. Moving to next.
# Trained fit 75700/82500. Moving to next.
# Trained fit 75750/82500. Moving to next.
# Trained fit 75800/82500. Moving to next.
# Trained fit 75850/82500. Moving to next.
# Trained fit 75900/82500. Moving to next.
# Trained fit 75950/82500. Moving to next.
# Trained fit 76000/82500. Moving to next.
# Trained fit 76050/82500. Moving to next.
# Trained fit 76100/82500. Moving to next.
# Trained fit 76150/82500. Moving to next.
# Trained fit 76200/82500. Moving to next.
# Trained fit 76250/82500. Moving to next.
# Trained fit 76300/82500. Moving to next.
# Trained fit 76350/82500. Moving to next.
# Trained fit 76400/82500. Moving to next.
# Trained fit 76450/82500. Moving to next.
# Trained fit 76500/82500. Moving to next.
# Trained fit 76550/82500. Moving to next.
# Trained fit 76600/82500. Moving to next.
# Trained fit 76650/82500. Moving to next.
# Trained fit 76700/82500. Moving to next.
# Trained fit 76750/82500. Moving to next.
# Trained fit 76800/82500. Moving to next.
# Trained fit 76850/82500. Moving to next.
# Trained fit 76900/82500. Moving to next.
# Trained fit 76950/82500. Moving to next.
# Trained fit 77000/82500. Moving to next.
# Trained fit 77050/82500. Moving to next.
# Trained fit 77100/82500. Moving to next.
# Trained fit 77150/82500. Moving to next.
# Trained fit 77200/82500. Moving to next.
# Trained fit 77250/82500. Moving to next.
# Trained fit 77300/82500. Moving to next.
# Trained fit 77350/82500. Moving to next.
# Trained fit 77400/82500. Moving to next.
# Trained fit 77450/82500. Moving to next.
# Trained fit 77500/82500. Moving to next.
# Trained fit 77550/82500. Moving to next.
# Trained fit 77600/82500. Moving to next.
# Trained fit 77650/82500. Moving to next.
# Trained fit 77700/82500. Moving to next.
# Trained fit 77750/82500. Moving to next.
# Trained fit 77800/82500. Moving to next.
# Trained fit 77850/82500. Moving to next.
# Trained fit 77900/82500. Moving to next.
# Trained fit 77950/82500. Moving to next.
# Trained fit 78000/82500. Moving to next.
# Trained fit 78050/82500. Moving to next.
# Trained fit 78100/82500. Moving to next.
# Trained fit 78150/82500. Moving to next.
# Trained fit 78200/82500. Moving to next.
# Trained fit 78250/82500. Moving to next.
# Trained fit 78300/82500. Moving to next.
# Trained fit 78350/82500. Moving to next.
# Trained fit 78400/82500. Moving to next.
# Trained fit 78450/82500. Moving to next.
# Trained fit 78500/82500. Moving to next.
# Trained fit 78550/82500. Moving to next.
# Trained fit 78600/82500. Moving to next.
# Trained fit 78650/82500. Moving to next.
# Trained fit 78700/82500. Moving to next.
# Trained fit 78750/82500. Moving to next.
# Trained fit 78800/82500. Moving to next.
# Trained fit 78850/82500. Moving to next.
# Trained fit 78900/82500. Moving to next.
# Trained fit 78950/82500. Moving to next.
# Trained fit 79000/82500. Moving to next.
# Trained fit 79050/82500. Moving to next.
# Trained fit 79100/82500. Moving to next.
# Trained fit 79150/82500. Moving to next.
# Trained fit 79200/82500. Moving to next.
# Trained fit 79250/82500. Moving to next.
# Trained fit 79300/82500. Moving to next.
# Trained fit 79350/82500. Moving to next.
# Trained fit 79400/82500. Moving to next.
# Trained fit 79450/82500. Moving to next.
# Trained fit 79500/82500. Moving to next.
# Trained fit 79550/82500. Moving to next.
# Trained fit 79600/82500. Moving to next.
# Trained fit 79650/82500. Moving to next.
# Trained fit 79700/82500. Moving to next.
# Trained fit 79750/82500. Moving to next.
# Trained fit 79800/82500. Moving to next.
# Trained fit 79850/82500. Moving to next.
# Trained fit 79900/82500. Moving to next.
# Trained fit 79950/82500. Moving to next.
# Trained fit 80000/82500. Moving to next.
# Trained fit 80050/82500. Moving to next.
# Trained fit 80100/82500. Moving to next.
# Trained fit 80150/82500. Moving to next.
# Trained fit 80200/82500. Moving to next.
# Trained fit 80250/82500. Moving to next.
# Trained fit 80300/82500. Moving to next.
# Trained fit 80350/82500. Moving to next.
# Trained fit 80400/82500. Moving to next.
# Trained fit 80450/82500. Moving to next.
# Trained fit 80500/82500. Moving to next.
# Trained fit 80550/82500. Moving to next.
# Trained fit 80600/82500. Moving to next.
# Trained fit 80650/82500. Moving to next.
# Trained fit 80700/82500. Moving to next.
# Trained fit 80750/82500. Moving to next.
# Trained fit 80800/82500. Moving to next.
# Trained fit 80850/82500. Moving to next.
# Trained fit 80900/82500. Moving to next.
# Trained fit 80950/82500. Moving to next.
# Trained fit 81000/82500. Moving to next.
# Trained fit 81050/82500. Moving to next.
# Trained fit 81100/82500. Moving to next.
# Trained fit 81150/82500. Moving to next.
# Trained fit 81200/82500. Moving to next.
# Trained fit 81250/82500. Moving to next.
# Trained fit 81300/82500. Moving to next.
# Trained fit 81350/82500. Moving to next.
# Trained fit 81400/82500. Moving to next.
# Trained fit 81450/82500. Moving to next.
# Trained fit 81500/82500. Moving to next.
# Trained fit 81550/82500. Moving to next.
# Trained fit 81600/82500. Moving to next.
# Trained fit 81650/82500. Moving to next.
# Trained fit 81700/82500. Moving to next.
# Trained fit 81750/82500. Moving to next.
# Trained fit 81800/82500. Moving to next.
# Trained fit 81850/82500. Moving to next.
# Trained fit 81900/82500. Moving to next.
# Trained fit 81950/82500. Moving to next.
# Trained fit 82000/82500. Moving to next.
# Trained fit 82050/82500. Moving to next.
# Trained fit 82100/82500. Moving to next.
# Trained fit 82150/82500. Moving to next.
# Trained fit 82200/82500. Moving to next.
# Trained fit 82250/82500. Moving to next.
# Trained fit 82300/82500. Moving to next.
# Trained fit 82350/82500. Moving to next.
# Trained fit 82400/82500. Moving to next.
# Trained fit 82450/82500. Moving to next.
# Trained fit 82500/82500. Moving to next.
#
# Best Model Found:
# Best Parameters: {'alpha': 0, 'colsample_bytree': 0.075, 'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.3, 'max_depth': 7, 'n_estimators': 25, 'subsample': 1.0}
# Best Validation RMSE: 791.2663

# %%
# Generate scatterplot for the best model
if best_model:
    # Get predictions from the best model
    y_pred_scaled = best_model.predict(X_val_scaled)

    # **Inverse transform predictions and actual values**
    y_pred = outyscaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Scatterplot of predicted vs actual
    plt.figure(figsize=(6, 6))
    plt.scatter(y_Outflow_val, y_pred, alpha=0.5)

    # Plot y = x line for reference
    min_val, max_val = min(y_Outflow_val.min(), y_pred.min()), max(y_Outflow_val.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], linestyle="--", color="red", label="Ideal Fit")

    # Set log scale
    plt.xscale("log")
    plt.yscale("log")
    
    # Labels and title
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title(f"Best XGBoost Model: Out-of-Sample Performance")
    plt.legend()

    # Show the plot
    plt.show()

# Generate scatterplot for the best model
if best_model:
    # Get predictions from the best model
    y_pred_scaled = best_model.predict(X_val_scaled)

    # **Inverse transform predictions and actual values**
    y_pred = outyscaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Scatterplot of predicted vs actual
    plt.figure(figsize=(6, 6))
    plt.scatter(y_Outflow_val, y_pred, alpha=0.5)

    # Plot y = x line for reference
    min_val, max_val = min(y_Outflow_val.min(), y_pred.min()), max(y_Outflow_val.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], linestyle="--", color="red", label="Ideal Fit")
    
    # Labels and title
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title(f"Best XGBoost Model: Out-of-Sample Performance")
    plt.legend()

    # Show the plot
    plt.show()

# %%
# Compute validation MSE on the original scale
val_mse_original_scale = mean_squared_error(y_Outflow_val_scaled, y_pred)
print(f"Validation MSE (Original Scale): {val_mse_original_scale:.4f}")
val_rmse_original_scale = np.sqrt(mean_squared_error(y_Outflow_val, y_pred))
print(f"Validation RMSE (Original Scale): {val_rmse_original_scale:.4f}")
# Out:
# Validation MSE (Original Scale): 1204139.8586
# Validation RMSE (Original Scale): 791.2663

# %%
import pandas as pd

# Calculate residuals (difference between actual and predicted values)
residuals = y_Outflow_val - y_pred

# Create a DataFrame to store actual values, predicted values, and residuals for easy manipulation
residuals_df = pd.DataFrame({
    'Actual': y_Outflow_val,
    'Predicted': y_pred,
    'Residual': residuals
})

# Sort the DataFrame by absolute residuals (descending order)
sorted_residuals_df = residuals_df.reindex(residuals_df['Residual'].abs().sort_values(ascending=False).index)

# Display the top N rows with the largest residuals
top_n = 10  # You can change this number to see more or fewer rows
print(f"Top {top_n} data points with largest residuals:")
print(sorted_residuals_df.head(top_n))
# Out:
# Top 10 data points with largest residuals:
#      Actual    Predicted     Residual
# 411  8299.0  3961.111816  4337.888184
# 103  3172.0   477.116913  2694.883087
# 551   214.0  2291.188721 -2077.188721
# 131  2365.0   328.820526  2036.179474
# 383   339.0  2082.831787 -1743.831787
# 5     138.0  1349.160645 -1211.160645
# 502   199.0  1237.148315 -1038.148315
# 138   823.0  1805.963745  -982.963745
# 390   371.0  1308.922729  -937.922729
# 110  1815.0   926.595886   888.404114

# %%
# In-sample accuracy for trainPLUSval set

# Initialize the best model with the optimal parameters found
best_model = xgboost.XGBRegressor(**best_params, random_state=42)

# Train on the combined dataset
best_model.fit(X_trainPLUSval_scaled, y_Outflow_trainPLUSval_scaled)

# Predict on the train+val set
y_trainval_pred_scaled = best_model.predict(X_trainPLUSval_scaled)

# Compute in-sample RMSE (on scaled values)
trainval_rmse_scaled = np.sqrt(mean_squared_error(y_Outflow_trainPLUSval_scaled, y_trainval_pred_scaled))

# Convert RMSE back to original scale
trainval_rmse_original = outyscaler.inverse_transform([[trainval_rmse_scaled]])[0, 0]

# Print final results
print("\nFinal Model Trained on Train + Validation Set")
print(f"Selected Parameters: {best_params}")
print(f"In-sample RMSE: {trainval_rmse_scaled:.4f}")

# Generate scatterplot for the best model
if best_model:
    # Get predictions from the best model
    y_pred_scaled = best_model.predict(X_trainPLUSval_scaled)

    # **Inverse transform predictions and actual values**
    y_pred = outyscaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Scatterplot of predicted vs actual
    plt.figure(figsize=(6, 6))
    plt.scatter(y_Outflow_trainPLUSval, y_pred, alpha=0.5)

    # Plot y = x line for reference
    min_val, max_val = min(y_Outflow_trainPLUSval.min(), y_pred.min()), max(y_Outflow_trainPLUSval.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], linestyle="--", color="red", label="Ideal Fit")
    
    # Labels and title
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title(f"XGBoost: In-Sample Performance")
    plt.legend()

    plt.xscale('log')
    plt.yscale('log')

    # Show the plot
    plt.show()
# Out:
# Final Model Trained on Train + Validation Set
# Selected Parameters: {'alpha': 0, 'colsample_bytree': 0.075, 'gamma': 0.1, 'lambda': 0.3, 'learning_rate': 0.3, 'max_depth': 7, 'n_estimators': 25, 'subsample': 1.0}
# In-sample RMSE: 0.0894

# %%
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import numpy as np

# Compute permutation importance
result = permutation_importance(
    best_model, X_trainPLUSval_scaled, y_Outflow_trainPLUSval_scaled, 
    scoring='neg_root_mean_squared_error', n_repeats=10, random_state=42
)

feature_names = X_trainPLUSval.columns  # Extract column names

# Sort by importance
sorted_idx = result.importances_mean.argsort()

# Select bottom 10 (least important) and top 10 (most important) features
bottom_10_idx = sorted_idx[:10]  # First 10 (least important)
top_10_idx = sorted_idx[-10:]    # Last 10 (most important)

# Plot bottom 10 features
plt.figure(figsize=(8, 6))
plt.barh(np.array(feature_names)[bottom_10_idx], result.importances_mean[bottom_10_idx], 
         xerr=result.importances_std[bottom_10_idx], capsize=4, color="gray")
plt.xlabel("Permutation Importance (Change in RMSE)")
plt.ylabel("Feature")
plt.title("Bottom 10 Feature Importance in XGBoost")
plt.show()

# Plot top 10 features
plt.figure(figsize=(8, 6))
plt.barh(np.array(feature_names)[top_10_idx], result.importances_mean[top_10_idx], 
         xerr=result.importances_std[top_10_idx], capsize=4, color="blue")
plt.xlabel("Permutation Importance (Change in RMSE)")
plt.ylabel("Feature")
plt.title("Top 10 Feature Importance in XGBoost")
plt.show()

# %%
# Predict on the train+val set
X_scaled = X_scaled.drop(columns="Year")
y_Outflows_fitted_values = best_model.predict(X_scaled)

# %%
# Add the 'Year' column back to the X_scaled DataFrame
year_column = X['Year']
X_scaled['Year'] = year_column

X_scaled.reset_index(drop=True, inplace=True)
y_Outflows_fitted_values = y_Outflows_fitted_values[:X_scaled.shape[0]]  # Make sure y values match X's number of rows

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assume 'best_model' is your fitted model and 'X_scaled' is your training data with region dummies
# Identify the region columns (columns that contain 'Region' in their name)
region_columns = X_scaled.filter(regex='Region').columns

# Randomly select 10 regions from the available dummy columns
random_regions = np.random.choice(region_columns, size=10, replace=False)

# Extract 'Year' from X_scaled (assuming it's in the original X matrix, which might have been scaled)
years = X_scaled['Year'].unique()

# Create a plot
plt.figure(figsize=(10, 6))

# Loop through the random regions to plot their corresponding fitted values over time (Years)
for region in random_regions:
    # Select rows where the region dummy variable is 1 (indicating that the region applies to that row)
    region_data_indices = X_scaled[X_scaled[region] == 1].index
    
    # Extract the corresponding years and fitted values for this region
    region_years = X_scaled.loc[region_data_indices, 'Year']
    region_fitted_values = y_Outflows_fitted_values[region_data_indices]
    
    # Inverse transform the fitted values using y_scaler
    region_fitted_values = outyscaler.inverse_transform(region_fitted_values.reshape(-1, 1)).flatten()
    
    # Plot fitted values for this region over the years
    plt.plot(region_years, region_fitted_values, label=region, marker='o')

# Add labels and legend
plt.xlabel('Year')
plt.ylabel('Fitted Outflows')
plt.title('Fitted Outflows for 10 Selected Regions Over Time')
plt.legend(title="Regions", bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# Number of bootstrap iterations
n_iterations = 1000
predictions = []

# Initialize list to collect results
results = []

# Perform bootstrapping
for i in range(n_iterations):
    # Resample the data with replacement
    X_resampled, y_resampled = resample(X_trainPLUSval_scaled, y_Outflow_trainPLUSval_scaled, random_state=i)
    
    # Fit the model on the resampled data
    best_model.fit(X_resampled, y_resampled)
    
    # Predict the values for the resampled data
    y_pred_resampled = best_model.predict(X_resampled)
    
    # Store the predictions
    predictions.append(y_pred_resampled)

# Convert predictions list to a numpy array
predictions = np.array(predictions)
std_deviation = np.std(predictions, axis=0)

# %%
# Create the 90% confidence interval using +/- 1.645 standard deviations (for 90% CI)
std_deviation_mean = np.mean(std_deviation)
conf_interval_factor = 1.645  # For 90% confidence interval
lower_bound = y_Outflows_fitted_values - conf_interval_factor * std_deviation_mean
upper_bound = y_Outflows_fitted_values + conf_interval_factor * std_deviation_mean

# %%
# Reshape to 2D before applying inverse_transform if the scaler was fit on multiple columns
y_Outflows_fitted_values = outyscaler.inverse_transform(y_Outflows_fitted_values.reshape(-1, 1))  # Reshape to 2D
lower_bound = outyscaler.inverse_transform(lower_bound.reshape(-1, 1))  # Reshape to 2D
upper_bound = outyscaler.inverse_transform(upper_bound.reshape(-1, 1))  # Reshape to 2D

# Flatten to return to 1D after inverse transformation
y_Outflows_fitted_values = y_Outflows_fitted_values.flatten()
lower_bound = lower_bound.flatten()
upper_bound = upper_bound.flatten()

# Create a DataFrame with Year, fitted values, lower and upper bounds
df_fitted_values = pd.DataFrame({
    'Year': year_column, 
    'Region' : region_year_copy['Region'],
    'Fitted Values': y_Outflows_fitted_values,  # Your fitted values
    'Lower Bound': lower_bound,  # Lower confidence interval bound
    'Upper Bound': upper_bound  # Upper confidence interval bound
})

# Display the resulting DataFrame
print(df_fitted_values.head(100))
# Out:
#      Year                      Region  Fitted Values  Lower Bound  Upper Bound
# 1    2019                  Altai Krai     351.458313 -1512.735718  2215.652100
# 2    2020                  Altai Krai     183.295441 -1680.898315  2047.489502
# 3    2021                  Altai Krai     224.766235 -1639.427856  2088.959961
# 4    2022                  Altai Krai     343.641266 -1520.552612  2207.835205
# 5    2023                  Altai Krai     174.246033 -1689.947876  2038.439941
# ..    ...                         ...            ...          ...          ...
# 111  2024              Kamchatka Krai    2109.405762   245.211975  3973.599854
# 113  2019  Karachay-Cherkess Republic      54.441185 -1809.752808  1918.635132
# 114  2020  Karachay-Cherkess Republic      74.710075 -1789.483765  1938.904053
# 115  2021  Karachay-Cherkess Republic      52.537315 -1811.656616  1916.731201
# 116  2022  Karachay-Cherkess Republic      65.571953 -1798.621948  1929.765869
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Plot histogram for the inverse-transformed fitted values, lower bound, and upper bound
plt.figure(figsize=(10, 6))

# Plot histogram for Fitted Values
plt.hist(df_fitted_values['Fitted Values'], bins=30, alpha=0.5, label='Fitted Values', color='blue')

# Plot histogram for Lower Bound
plt.hist(df_fitted_values['Lower Bound'], bins=30, alpha=0.5, label='Lower Bound', color='red')

# Plot histogram for Upper Bound
plt.hist(df_fitted_values['Upper Bound'], bins=30, alpha=0.5, label='Upper Bound', color='green')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Fitted Values and Confidence Intervals—Outflows')
plt.legend(loc='upper right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Optionally, save the DataFrame to a CSV file for further analysis
df_fitted_values.to_csv('/Users/michelle/Documents/thesis/extended_time_series_OUTflows_NOeconomiccovariates.csv', index=False)

# %% [markdown]
# ### Repeat this process for outflows

# %% [markdown]
# ### Repeat this process for outflows

# %% [markdown]
# ## __Part 2:__ Extending the 2010-16 monthly stock dataset
